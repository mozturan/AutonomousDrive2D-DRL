# %%
# fundemental modules
import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
import time
import pprint
from tqdm.notebook import trange

from ddqn import DDQNAgent # type: ignore
from utils import load_config
from obs import observation_shape

aggregate_stats_every=100
best_score = -1000.0
score_history = []
episode_lens = []
avg_history = []
std_history = []
avg_history_100 = []
# Out:
# 2023-12-04 14:23:44.549563: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-04 14:23:44.572312: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-04 14:23:44.572331: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-04 14:23:44.572344: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-04 14:23:44.576778: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = load_config()
env = gym.make('racetrack-v0', render_mode = 'rgb_array')
env.configure(data) # type: ignore
# pprint.pprint(env.config) # type: ignore
(obs, info), done = env.reset(), False

#observation config
proc = observation_shape(obs,info,2)
proc.reset()
input = proc.get_input()
print(input.shape)
# Out:
# (26,)
# /home/o/Documents/thesis/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.configure to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.configure` for environment variables or `env.get_wrapper_attr('configure')` that will search the reminding wrappers.
#   logger.warn(

# %%
agent = DDQNAgent(alpha=0.001, gamma=0.9, epsilon=1.0, obs_shape=input.shape,
                  batch_size=64, epsilon_dec=0.999, epsilon_end=0.05, mem_size=100000,
                  min_mem_size=100, replace_target=1000, learning_rate=0.0003)
print("Agent is initialized.")
# Out:
# 2023-12-04 14:23:48.982266: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 14:23:49.002749: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 14:23:49.002992: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               3456
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 21387 (83.54 KB)
# Trainable params: 21387 (83.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# summary
# Agent is initialized.
# 2023-12-04 14:23:49.004251: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 14:23:49.004328: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 14:23:49.004478: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 14:23:49.323512: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 14:23:49.323598: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 14:23:49.323649: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 14:23:49.323689: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9892 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# main loop
for episode in trange(500, desc='Test episodes'):

        proc.reset()
        (observation, info), done = env.reset(), False
        truncated = False
        proc.update_input(observation, info)
        observation = proc.get_input()

        episode_reward = 0
        episode_len = 0

        while (not done) and (not truncated):
            
            action, action_index = agent.get_action(observation, deterministic=False)
            new_observation, reward, done, truncated, new_info = env.step(action=[action])
            
            proc.update_input(new_observation, info)
            new_observation = proc.get_input()

            episode_reward += reward # type: ignore
            episode_len +=1

            if new_info["rewards"]["on_road_reward"] == False or episode_len >= 200:
                truncated = True
            
            agent.remember(state=observation, action=action_index, done=done,
                            reward=reward, new_state=new_observation)
            agent.train()

            observation = new_observation

        episode_lens.append(episode_len)

        score_history.append(episode_reward)
        avg_score = np.mean(score_history)
        avg_history.append(avg_score)
        std_score = np.std(score_history)
        std_history.append(std_score)

        avg_score_100 = np.mean(score_history[-100:])
        avg_history_100.append(avg_score_100)

        if avg_score_100 > best_score:
            best_score = avg_score
            agent.save_model(episode)

        agent.tensorboard.update_stats(episode_rew = episode_reward,
                                       average_rew =avg_score,
                                       average_100_reward = avg_score_100,
                                       std_rew=std_score,
                                       epsilon=agent.epsilon,
                                       episode_len = episode_len)
        

        print('episode ', episode, 'score %.1f' % episode_reward, 'ep len', episode_len,
              'avg score %.1f' % avg_score, 'avg_score_100 %.1f' %avg_score_100,'std score %.1f' % std_score)
# Out:
# Test episodes:   0%|          | 0/500 [00:00<?, ?it/s]
# -----saving models------
# 2023-12-04 14:24:10.818706: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# episode  0 score 0.1 ep len 25 avg score 0.1 avg_score_100 0.1 std score 0.0
# -----saving models------
# episode  1 score 1.7 ep len 4 avg score 0.9 avg_score_100 0.9 std score 0.8
# -----saving models------
# episode  2 score 1.6 ep len 9 avg score 1.1 avg_score_100 1.1 std score 0.7
# episode  3 score 0.8 ep len 14 avg score 1.0 avg_score_100 1.0 std score 0.7
# episode  4 score -0.3 ep len 6 avg score 0.8 avg_score_100 0.8 std score 0.8
# -----saving models------
# episode  5 score 5.8 ep len 27 avg score 1.6 avg_score_100 1.6 std score 2.0
# -----saving models------
# episode  6 score 2.1 ep len 7 avg score 1.7 avg_score_100 1.7 std score 1.9
# 2023-12-04 14:24:12.531836: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7feabc2b46a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-04 14:24:12.531852: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2023-12-04 14:24:12.534657: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-04 14:24:13.394143: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8902
# 2023-12-04 14:24:13.446995: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# episode  7 score 1.0 ep len 10 avg score 1.6 avg_score_100 1.6 std score 1.8
# episode  8 score 0.6 ep len 7 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  9 score 1.1 ep len 9 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  10 score 3.1 ep len 14 avg score 1.6 avg_score_100 1.6 std score 1.6
# -----saving models------
# episode  11 score 3.6 ep len 15 avg score 1.8 avg_score_100 1.8 std score 1.6
# -----saving models------
# episode  12 score 4.3 ep len 13 avg score 2.0 avg_score_100 2.0 std score 1.7
# episode  13 score 1.1 ep len 5 avg score 1.9 avg_score_100 1.9 std score 1.7
# episode  14 score 0.6 ep len 4 avg score 1.8 avg_score_100 1.8 std score 1.6
# episode  15 score -0.2 ep len 3 avg score 1.7 avg_score_100 1.7 std score 1.7
# episode  16 score 0.0 ep len 3 avg score 1.6 avg_score_100 1.6 std score 1.6
# episode  17 score -0.2 ep len 3 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  18 score 0.3 ep len 6 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  19 score 0.1 ep len 4 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  20 score 0.2 ep len 7 avg score 1.3 avg_score_100 1.3 std score 1.6
# episode  21 score 3.4 ep len 15 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  22 score 1.4 ep len 22 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  23 score 1.6 ep len 18 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  24 score 3.1 ep len 6 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  25 score 1.4 ep len 5 avg score 1.5 avg_score_100 1.5 std score 1.5
# episode  26 score 0.6 ep len 10 avg score 1.4 avg_score_100 1.4 std score 1.5
# episode  27 score 2.2 ep len 10 avg score 1.5 avg_score_100 1.5 std score 1.5
# episode  28 score 2.7 ep len 12 avg score 1.5 avg_score_100 1.5 std score 1.5
# episode  29 score 1.7 ep len 12 avg score 1.5 avg_score_100 1.5 std score 1.5
# episode  30 score -0.0 ep len 6 avg score 1.5 avg_score_100 1.5 std score 1.5
# episode  31 score 0.6 ep len 7 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  32 score 3.3 ep len 11 avg score 1.5 avg_score_100 1.5 std score 1.5
# episode  33 score 2.7 ep len 11 avg score 1.5 avg_score_100 1.5 std score 1.4
# episode  34 score 2.7 ep len 17 avg score 1.6 avg_score_100 1.6 std score 1.4
# episode  35 score 1.6 ep len 6 avg score 1.6 avg_score_100 1.6 std score 1.4
# episode  36 score 1.7 ep len 8 avg score 1.6 avg_score_100 1.6 std score 1.4
# episode  37 score 0.9 ep len 3 avg score 1.5 avg_score_100 1.5 std score 1.4
# episode  38 score 0.6 ep len 6 avg score 1.5 avg_score_100 1.5 std score 1.4
# episode  39 score 0.1 ep len 3 avg score 1.5 avg_score_100 1.5 std score 1.4
# episode  40 score 0.6 ep len 15 avg score 1.5 avg_score_100 1.5 std score 1.4
# episode  41 score -0.1 ep len 3 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  42 score 3.0 ep len 19 avg score 1.5 avg_score_100 1.5 std score 1.4
# episode  43 score 0.4 ep len 6 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  44 score 1.4 ep len 10 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  45 score -0.3 ep len 5 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  46 score -0.1 ep len 2 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  47 score 3.3 ep len 12 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  48 score 3.3 ep len 11 avg score 1.5 avg_score_100 1.5 std score 1.4
# episode  49 score 1.2 ep len 13 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  50 score -0.1 ep len 2 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  51 score 0.1 ep len 10 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  52 score -0.2 ep len 3 avg score 1.4 avg_score_100 1.4 std score 1.4
# episode  53 score 9.1 ep len 29 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  54 score 2.1 ep len 13 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  55 score 0.8 ep len 8 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  56 score 1.1 ep len 6 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  57 score 0.0 ep len 3 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  58 score 2.4 ep len 13 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  59 score 1.7 ep len 4 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  60 score 4.5 ep len 17 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  61 score -0.2 ep len 3 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  62 score 0.4 ep len 9 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  63 score 2.1 ep len 9 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  64 score 0.7 ep len 7 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  65 score -0.5 ep len 9 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  66 score 4.1 ep len 16 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  67 score 1.3 ep len 8 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  68 score 0.2 ep len 4 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  69 score 1.9 ep len 7 avg score 1.5 avg_score_100 1.5 std score 1.7
# episode  70 score 0.3 ep len 3 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  71 score 0.1 ep len 4 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  72 score -0.4 ep len 4 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  73 score 0.8 ep len 4 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  74 score 0.2 ep len 3 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  75 score 0.8 ep len 12 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  76 score 1.1 ep len 5 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  77 score 3.5 ep len 8 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  78 score 0.0 ep len 3 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  79 score 0.7 ep len 3 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  80 score 2.3 ep len 22 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  81 score 2.9 ep len 24 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  82 score 0.3 ep len 4 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  83 score 0.5 ep len 5 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  84 score 0.6 ep len 3 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  85 score 0.3 ep len 17 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  86 score 0.7 ep len 4 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  87 score 1.6 ep len 15 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  88 score 1.6 ep len 5 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  89 score 4.4 ep len 22 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  90 score 3.6 ep len 15 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  91 score 1.2 ep len 7 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  92 score 2.2 ep len 19 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  93 score 1.1 ep len 11 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  94 score 5.9 ep len 14 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  95 score 0.7 ep len 10 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  96 score -0.2 ep len 3 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  97 score 0.6 ep len 3 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  98 score 0.9 ep len 9 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  99 score 0.9 ep len 3 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  100 score 1.1 ep len 5 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  101 score 1.7 ep len 10 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  102 score 2.2 ep len 12 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  103 score 0.4 ep len 4 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  104 score 0.7 ep len 13 avg score 1.4 avg_score_100 1.5 std score 1.6
# episode  105 score 2.5 ep len 17 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  106 score 1.2 ep len 9 avg score 1.4 avg_score_100 1.4 std score 1.6
# episode  107 score 1.2 ep len 4 avg score 1.4 avg_score_100 1.4 std score 1.5
# episode  108 score 2.9 ep len 24 avg score 1.4 avg_score_100 1.4 std score 1.5
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# episode  109 score 1.8 ep len 8 avg score 1.4 avg_score_100 1.4 std score 1.5
# Target Updated
# Target Updated
# Target Updated
# episode  110 score 3.8 ep len 11 avg score 1.5 avg_score_100 1.4 std score 1.5
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# episode  111 score -0.1 ep len 4 avg score 1.4 avg_score_100 1.4 std score 1.5
# Target Updated
# Target Updated
# Target Updated
# episode  112 score 7.2 ep len 12 avg score 1.5 avg_score_100 1.4 std score 1.6
# episode  113 score 2.1 ep len 12 avg score 1.5 avg_score_100 1.4 std score 1.6
# episode  114 score 2.0 ep len 16 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  115 score 0.3 ep len 7 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  116 score 3.7 ep len 11 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  117 score 1.1 ep len 17 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  118 score 3.8 ep len 8 avg score 1.5 avg_score_100 1.6 std score 1.6
# episode  119 score 0.0 ep len 3 avg score 1.5 avg_score_100 1.6 std score 1.6
# episode  120 score 0.1 ep len 5 avg score 1.5 avg_score_100 1.6 std score 1.6
# episode  121 score 3.2 ep len 25 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  122 score 1.1 ep len 11 avg score 1.5 avg_score_100 1.5 std score 1.6
# episode  123 score 6.3 ep len 22 avg score 1.6 avg_score_100 1.6 std score 1.7
# episode  124 score 6.7 ep len 22 avg score 1.6 avg_score_100 1.6 std score 1.7
# episode  125 score 3.7 ep len 22 avg score 1.6 avg_score_100 1.7 std score 1.7
# episode  126 score 6.4 ep len 27 avg score 1.7 avg_score_100 1.7 std score 1.8
# episode  127 score 4.2 ep len 24 avg score 1.7 avg_score_100 1.7 std score 1.8
# episode  128 score 6.5 ep len 25 avg score 1.7 avg_score_100 1.8 std score 1.8
# episode  129 score 2.4 ep len 13 avg score 1.7 avg_score_100 1.8 std score 1.8
# episode  130 score 3.4 ep len 18 avg score 1.7 avg_score_100 1.8 std score 1.8
# episode  131 score 0.6 ep len 8 avg score 1.7 avg_score_100 1.8 std score 1.8
# episode  132 score 0.5 ep len 5 avg score 1.7 avg_score_100 1.8 std score 1.8
# episode  133 score 6.2 ep len 21 avg score 1.7 avg_score_100 1.8 std score 1.8
# episode  134 score 1.2 ep len 12 avg score 1.7 avg_score_100 1.8 std score 1.8
# episode  135 score 2.6 ep len 10 avg score 1.7 avg_score_100 1.8 std score 1.8
# episode  136 score 2.4 ep len 21 avg score 1.7 avg_score_100 1.8 std score 1.8
# episode  137 score 2.6 ep len 14 avg score 1.8 avg_score_100 1.8 std score 1.8
# episode  138 score 2.1 ep len 6 avg score 1.8 avg_score_100 1.8 std score 1.8
# episode  139 score 6.1 ep len 21 avg score 1.8 avg_score_100 1.9 std score 1.8
# -----saving models------
# episode  140 score 5.2 ep len 11 avg score 1.8 avg_score_100 2.0 std score 1.9
# -----saving models------
# episode  141 score 0.1 ep len 9 avg score 1.8 avg_score_100 2.0 std score 1.8
# -----saving models------
# episode  142 score 1.4 ep len 12 avg score 1.8 avg_score_100 1.9 std score 1.8
# -----saving models------
# episode  143 score 4.1 ep len 24 avg score 1.8 avg_score_100 2.0 std score 1.8
# -----saving models------
# episode  144 score 4.6 ep len 26 avg score 1.8 avg_score_100 2.0 std score 1.9
# -----saving models------
# episode  145 score 3.9 ep len 17 avg score 1.8 avg_score_100 2.1 std score 1.9
# -----saving models------
# episode  146 score 1.5 ep len 11 avg score 1.8 avg_score_100 2.1 std score 1.8
# -----saving models------
# episode  147 score -0.4 ep len 5 avg score 1.8 avg_score_100 2.0 std score 1.9
# -----saving models------
# episode  148 score 5.9 ep len 22 avg score 1.9 avg_score_100 2.1 std score 1.9
# -----saving models------
# episode  149 score 0.1 ep len 3 avg score 1.8 avg_score_100 2.0 std score 1.9
# -----saving models------
# episode  150 score 2.2 ep len 12 avg score 1.8 avg_score_100 2.1 std score 1.9
# -----saving models------
# episode  151 score 1.5 ep len 23 avg score 1.8 avg_score_100 2.1 std score 1.9
# -----saving models------
# episode  152 score 10.5 ep len 25 avg score 1.9 avg_score_100 2.2 std score 2.0
# -----saving models------
# episode  153 score 1.0 ep len 12 avg score 1.9 avg_score_100 2.1 std score 2.0
# -----saving models------
# episode  154 score 4.4 ep len 20 avg score 1.9 avg_score_100 2.1 std score 2.0
# -----saving models------
# episode  155 score 0.8 ep len 5 avg score 1.9 avg_score_100 2.1 std score 2.0
# -----saving models------
# episode  156 score 6.3 ep len 22 avg score 1.9 avg_score_100 2.2 std score 2.0
# -----saving models------
# episode  157 score 2.8 ep len 9 avg score 1.9 avg_score_100 2.2 std score 2.0
# -----saving models------
# episode  158 score 5.2 ep len 28 avg score 2.0 avg_score_100 2.2 std score 2.0
# -----saving models------
# episode  159 score 0.5 ep len 7 avg score 1.9 avg_score_100 2.2 std score 2.0
# -----saving models------
# episode  160 score 6.6 ep len 22 avg score 2.0 avg_score_100 2.2 std score 2.0
# -----saving models------
# episode  161 score 8.4 ep len 21 avg score 2.0 avg_score_100 2.3 std score 2.1
# -----saving models------
# episode  162 score 4.5 ep len 22 avg score 2.0 avg_score_100 2.4 std score 2.1
# -----saving models------
# episode  163 score 7.5 ep len 26 avg score 2.1 avg_score_100 2.4 std score 2.1
# -----saving models------
# episode  164 score 0.3 ep len 11 avg score 2.1 avg_score_100 2.4 std score 2.1
# -----saving models------
# episode  165 score 2.4 ep len 10 avg score 2.1 avg_score_100 2.5 std score 2.1
# -----saving models------
# episode  166 score 5.6 ep len 19 avg score 2.1 avg_score_100 2.5 std score 2.1
# -----saving models------
# episode  167 score 4.2 ep len 23 avg score 2.1 avg_score_100 2.5 std score 2.1
# -----saving models------
# episode  168 score 0.5 ep len 4 avg score 2.1 avg_score_100 2.5 std score 2.1
# -----saving models------
# episode  169 score 8.9 ep len 22 avg score 2.1 avg_score_100 2.6 std score 2.2
# -----saving models------
# episode  170 score 3.7 ep len 10 avg score 2.1 avg_score_100 2.6 std score 2.2
# -----saving models------
# episode  171 score 2.6 ep len 19 avg score 2.1 avg_score_100 2.6 std score 2.2
# -----saving models------
# episode  172 score 7.0 ep len 27 avg score 2.2 avg_score_100 2.7 std score 2.2
# -----saving models------
# episode  173 score 1.6 ep len 18 avg score 2.2 avg_score_100 2.7 std score 2.2
# -----saving models------
# episode  174 score 4.2 ep len 20 avg score 2.2 avg_score_100 2.8 std score 2.2
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  175 score 3.7 ep len 14 avg score 2.2 avg_score_100 2.8 std score 2.2
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  176 score 9.0 ep len 25 avg score 2.2 avg_score_100 2.9 std score 2.2
# -----saving models------
# episode  177 score 4.7 ep len 21 avg score 2.2 avg_score_100 2.9 std score 2.2
# -----saving models------
# episode  178 score 2.1 ep len 10 avg score 2.2 avg_score_100 2.9 std score 2.2
# -----saving models------
# episode  179 score 1.2 ep len 6 avg score 2.2 avg_score_100 2.9 std score 2.2
# -----saving models------
# episode  180 score 12.4 ep len 21 avg score 2.3 avg_score_100 3.0 std score 2.4
# -----saving models------
# episode  181 score 3.8 ep len 9 avg score 2.3 avg_score_100 3.0 std score 2.3
# -----saving models------
# episode  182 score 3.3 ep len 14 avg score 2.3 avg_score_100 3.0 std score 2.3
# -----saving models------
# episode  183 score 4.8 ep len 9 avg score 2.3 avg_score_100 3.1 std score 2.3
# -----saving models------
# episode  184 score 4.5 ep len 20 avg score 2.3 avg_score_100 3.1 std score 2.3
# -----saving models------
# episode  185 score 3.7 ep len 10 avg score 2.3 avg_score_100 3.2 std score 2.3
# -----saving models------
# episode  186 score -0.0 ep len 4 avg score 2.3 avg_score_100 3.1 std score 2.3
# -----saving models------
# episode  187 score 3.4 ep len 29 avg score 2.3 avg_score_100 3.2 std score 2.3
# -----saving models------
# episode  188 score 24.6 ep len 37 avg score 2.4 avg_score_100 3.4 std score 2.8
# -----saving models------
# episode  189 score 8.6 ep len 31 avg score 2.5 avg_score_100 3.4 std score 2.9
# -----saving models------
# episode  190 score 11.3 ep len 27 avg score 2.5 avg_score_100 3.5 std score 2.9
# -----saving models------
# episode  191 score 7.2 ep len 31 avg score 2.5 avg_score_100 3.6 std score 2.9
# -----saving models------
# episode  192 score 2.5 ep len 10 avg score 2.5 avg_score_100 3.6 std score 2.9
# -----saving models------
# episode  193 score 7.8 ep len 28 avg score 2.6 avg_score_100 3.6 std score 2.9
# -----saving models------
# episode  194 score 2.4 ep len 8 avg score 2.6 avg_score_100 3.6 std score 2.9
# -----saving models------
# episode  195 score 4.8 ep len 21 avg score 2.6 avg_score_100 3.7 std score 2.9
# -----saving models------
# episode  196 score 4.8 ep len 14 avg score 2.6 avg_score_100 3.7 std score 2.9
# -----saving models------
# episode  197 score 5.9 ep len 22 avg score 2.6 avg_score_100 3.8 std score 2.9
# -----saving models------
# episode  198 score 9.2 ep len 19 avg score 2.6 avg_score_100 3.8 std score 3.0
# -----saving models------
# episode  199 score 5.0 ep len 11 avg score 2.7 avg_score_100 3.9 std score 3.0
# -----saving models------
# episode  200 score 3.6 ep len 21 avg score 2.7 avg_score_100 3.9 std score 3.0
# -----saving models------
# episode  201 score 12.0 ep len 15 avg score 2.7 avg_score_100 4.0 std score 3.0
# -----saving models------
# episode  202 score 5.9 ep len 9 avg score 2.7 avg_score_100 4.0 std score 3.0
# -----saving models------
# episode  203 score 7.0 ep len 24 avg score 2.7 avg_score_100 4.1 std score 3.0
# -----saving models------
# episode  204 score 7.3 ep len 21 avg score 2.8 avg_score_100 4.2 std score 3.0
# -----saving models------
# episode  205 score 10.4 ep len 36 avg score 2.8 avg_score_100 4.3 std score 3.1
# -----saving models------
# episode  206 score 2.7 ep len 26 avg score 2.8 avg_score_100 4.3 std score 3.1
# -----saving models------
# episode  207 score 2.7 ep len 11 avg score 2.8 avg_score_100 4.3 std score 3.1
# -----saving models------
# episode  208 score 11.9 ep len 24 avg score 2.8 avg_score_100 4.4 std score 3.1
# -----saving models------
# episode  209 score 3.7 ep len 19 avg score 2.8 avg_score_100 4.4 std score 3.1
# -----saving models------
# episode  210 score 9.4 ep len 22 avg score 2.9 avg_score_100 4.5 std score 3.1
# -----saving models------
# episode  211 score 1.7 ep len 9 avg score 2.9 avg_score_100 4.5 std score 3.1
# -----saving models------
# episode  212 score 1.9 ep len 23 avg score 2.9 avg_score_100 4.4 std score 3.1
# -----saving models------
# episode  213 score 4.6 ep len 27 avg score 2.9 avg_score_100 4.4 std score 3.1
# -----saving models------
# episode  214 score 5.9 ep len 11 avg score 2.9 avg_score_100 4.5 std score 3.1
# -----saving models------
# episode  215 score 10.9 ep len 23 avg score 2.9 avg_score_100 4.6 std score 3.2
# -----saving models------
# episode  216 score 11.8 ep len 21 avg score 3.0 avg_score_100 4.7 std score 3.2
# -----saving models------
# episode  217 score 11.7 ep len 36 avg score 3.0 avg_score_100 4.8 std score 3.3
# -----saving models------
# episode  218 score 11.6 ep len 24 avg score 3.0 avg_score_100 4.9 std score 3.3
# -----saving models------
# episode  219 score 12.9 ep len 20 avg score 3.1 avg_score_100 5.0 std score 3.4
# -----saving models------
# episode  220 score 5.1 ep len 23 avg score 3.1 avg_score_100 5.0 std score 3.3
# -----saving models------
# episode  221 score 5.0 ep len 15 avg score 3.1 avg_score_100 5.0 std score 3.3
# -----saving models------
# episode  222 score 11.5 ep len 47 avg score 3.1 avg_score_100 5.2 std score 3.4
# -----saving models------
# episode  223 score 9.1 ep len 12 avg score 3.2 avg_score_100 5.2 std score 3.4
# -----saving models------
# episode  224 score 3.2 ep len 23 avg score 3.2 avg_score_100 5.1 std score 3.4
# -----saving models------
# episode  225 score 9.0 ep len 22 avg score 3.2 avg_score_100 5.2 std score 3.4
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  226 score 8.4 ep len 20 avg score 3.2 avg_score_100 5.2 std score 3.4
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  227 score 4.7 ep len 10 avg score 3.2 avg_score_100 5.2 std score 3.4
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  228 score 2.2 ep len 23 avg score 3.2 avg_score_100 5.2 std score 3.4
# -----saving models------
# episode  229 score 8.8 ep len 34 avg score 3.2 avg_score_100 5.2 std score 3.4
# -----saving models------
# episode  230 score 7.0 ep len 44 avg score 3.3 avg_score_100 5.3 std score 3.4
# -----saving models------
# episode  231 score 11.3 ep len 38 avg score 3.3 avg_score_100 5.4 std score 3.4
# -----saving models------
# episode  232 score 17.7 ep len 36 avg score 3.4 avg_score_100 5.6 std score 3.6
# -----saving models------
# episode  233 score 12.2 ep len 39 avg score 3.4 avg_score_100 5.6 std score 3.6
# -----saving models------
# episode  234 score 6.8 ep len 34 avg score 3.4 avg_score_100 5.7 std score 3.6
# -----saving models------
# episode  235 score 11.5 ep len 21 avg score 3.4 avg_score_100 5.8 std score 3.6
# -----saving models------
# episode  236 score 9.7 ep len 33 avg score 3.5 avg_score_100 5.8 std score 3.7
# -----saving models------
# episode  237 score 8.5 ep len 35 avg score 3.5 avg_score_100 5.9 std score 3.7
# -----saving models------
# episode  238 score 16.7 ep len 48 avg score 3.6 avg_score_100 6.0 std score 3.7
# -----saving models------
# episode  239 score 8.2 ep len 23 avg score 3.6 avg_score_100 6.1 std score 3.8
# -----saving models------
# episode  240 score 13.9 ep len 26 avg score 3.6 avg_score_100 6.2 std score 3.8
# -----saving models------
# episode  241 score 9.3 ep len 32 avg score 3.6 avg_score_100 6.2 std score 3.8
# -----saving models------
# episode  242 score 6.2 ep len 37 avg score 3.6 avg_score_100 6.3 std score 3.8
# -----saving models------
# episode  243 score 16.6 ep len 41 avg score 3.7 avg_score_100 6.4 std score 3.9
# -----saving models------
# episode  244 score 6.4 ep len 34 avg score 3.7 avg_score_100 6.4 std score 3.9
# -----saving models------
# episode  245 score 13.1 ep len 40 avg score 3.7 avg_score_100 6.5 std score 3.9
# -----saving models------
# episode  246 score 10.8 ep len 41 avg score 3.8 avg_score_100 6.6 std score 3.9
# -----saving models------
# episode  247 score 5.5 ep len 20 avg score 3.8 avg_score_100 6.7 std score 3.9
# -----saving models------
# episode  248 score 12.8 ep len 41 avg score 3.8 avg_score_100 6.7 std score 4.0
# -----saving models------
# episode  249 score 13.0 ep len 24 avg score 3.9 avg_score_100 6.9 std score 4.0
# -----saving models------
# episode  250 score 13.6 ep len 44 avg score 3.9 avg_score_100 7.0 std score 4.0
# -----saving models------
# episode  251 score 23.3 ep len 45 avg score 4.0 avg_score_100 7.2 std score 4.2
# -----saving models------
# episode  252 score 3.4 ep len 11 avg score 4.0 avg_score_100 7.1 std score 4.2
# -----saving models------
# episode  253 score 15.9 ep len 68 avg score 4.0 avg_score_100 7.3 std score 4.3
# -----saving models------
# episode  254 score 17.4 ep len 76 avg score 4.1 avg_score_100 7.4 std score 4.3
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  255 score 17.7 ep len 48 avg score 4.1 avg_score_100 7.6 std score 4.4
# -----saving models------
# episode  256 score 19.0 ep len 71 avg score 4.2 avg_score_100 7.7 std score 4.5
# -----saving models------
# episode  257 score 28.0 ep len 80 avg score 4.3 avg_score_100 8.0 std score 4.7
# -----saving models------
# episode  258 score 27.5 ep len 77 avg score 4.4 avg_score_100 8.2 std score 4.9
# -----saving models------
# episode  259 score 20.6 ep len 72 avg score 4.4 avg_score_100 8.4 std score 5.0
# -----saving models------
# episode  260 score 8.0 ep len 16 avg score 4.4 avg_score_100 8.4 std score 5.0
# -----saving models------
# episode  261 score 14.8 ep len 43 avg score 4.5 avg_score_100 8.5 std score 5.0
# -----saving models------
# episode  262 score 26.1 ep len 65 avg score 4.6 avg_score_100 8.7 std score 5.2
# -----saving models------
# episode  263 score 35.4 ep len 83 avg score 4.7 avg_score_100 9.0 std score 5.5
# -----saving models------
# episode  264 score 28.1 ep len 79 avg score 4.8 avg_score_100 9.2 std score 5.7
# -----saving models------
# episode  265 score 36.2 ep len 82 avg score 4.9 avg_score_100 9.6 std score 6.0
# -----saving models------
# episode  266 score 35.3 ep len 85 avg score 5.0 avg_score_100 9.9 std score 6.3
# -----saving models------
# episode  267 score 37.8 ep len 83 avg score 5.1 avg_score_100 10.2 std score 6.6
# -----saving models------
# episode  268 score 14.0 ep len 32 avg score 5.2 avg_score_100 10.3 std score 6.6
# -----saving models------
# episode  269 score 21.5 ep len 51 avg score 5.2 avg_score_100 10.5 std score 6.7
# -----saving models------
# episode  270 score 35.7 ep len 77 avg score 5.3 avg_score_100 10.8 std score 6.9
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  271 score 31.9 ep len 74 avg score 5.4 avg_score_100 11.1 std score 7.1
# -----saving models------
# episode  272 score 39.2 ep len 80 avg score 5.5 avg_score_100 11.4 std score 7.3
# -----saving models------
# episode  273 score 45.9 ep len 75 avg score 5.7 avg_score_100 11.9 std score 7.7
# -----saving models------
# episode  274 score 47.0 ep len 86 avg score 5.8 avg_score_100 12.3 std score 8.1
# -----saving models------
# episode  275 score 39.6 ep len 76 avg score 6.0 avg_score_100 12.6 std score 8.3
# -----saving models------
# episode  276 score 30.4 ep len 74 avg score 6.1 avg_score_100 12.9 std score 8.5
# -----saving models------
# episode  277 score 46.2 ep len 92 avg score 6.2 avg_score_100 13.3 std score 8.8
# -----saving models------
# episode  278 score 29.4 ep len 75 avg score 6.3 avg_score_100 13.5 std score 8.9
# -----saving models------
# episode  279 score 58.0 ep len 132 avg score 6.5 avg_score_100 14.1 std score 9.4
# -----saving models------
# episode  280 score 40.4 ep len 73 avg score 6.6 avg_score_100 14.4 std score 9.6
# -----saving models------
# episode  281 score 30.4 ep len 76 avg score 6.7 avg_score_100 14.7 std score 9.7
# -----saving models------
# episode  282 score 40.4 ep len 92 avg score 6.8 avg_score_100 15.0 std score 9.8
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  283 score 67.0 ep len 154 avg score 7.0 avg_score_100 15.6 std score 10.5
# -----saving models------
# episode  284 score 44.4 ep len 76 avg score 7.1 avg_score_100 16.0 std score 10.7
# -----saving models------
# episode  285 score 71.1 ep len 151 avg score 7.4 avg_score_100 16.7 std score 11.3
# -----saving models------
# episode  286 score 80.3 ep len 146 avg score 7.6 avg_score_100 17.5 std score 12.1
# -----saving models------
# episode  287 score 44.3 ep len 65 avg score 7.7 avg_score_100 17.9 std score 12.2
# -----saving models------
# episode  288 score 78.4 ep len 137 avg score 8.0 avg_score_100 18.5 std score 12.9
# -----saving models------
# episode  289 score 81.3 ep len 136 avg score 8.2 avg_score_100 19.2 std score 13.6
# -----saving models------
# episode  290 score 84.4 ep len 148 avg score 8.5 avg_score_100 19.9 std score 14.3
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  291 score 99.6 ep len 200 avg score 8.8 avg_score_100 20.9 std score 15.2
# -----saving models------
# episode  292 score 22.8 ep len 34 avg score 8.9 avg_score_100 21.1 std score 15.2
# -----saving models------
# episode  293 score 80.1 ep len 161 avg score 9.1 avg_score_100 21.8 std score 15.7
# -----saving models------
# episode  294 score 20.4 ep len 30 avg score 9.1 avg_score_100 22.0 std score 15.7
# -----saving models------
# episode  295 score 96.3 ep len 200 avg score 9.4 avg_score_100 22.9 std score 16.5
# -----saving models------
# episode  296 score 96.1 ep len 200 avg score 9.7 avg_score_100 23.8 std score 17.2
# -----saving models------
# episode  297 score 104.7 ep len 200 avg score 10.0 avg_score_100 24.8 std score 18.0
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  298 score 96.3 ep len 147 avg score 10.3 avg_score_100 25.6 std score 18.7
# -----saving models------
# episode  299 score 91.0 ep len 158 avg score 10.6 avg_score_100 26.5 std score 19.2
# -----saving models------
# episode  300 score 99.1 ep len 200 avg score 10.9 avg_score_100 27.5 std score 19.9
# -----saving models------
# episode  301 score 80.9 ep len 177 avg score 11.1 avg_score_100 28.1 std score 20.2
# -----saving models------
# episode  302 score 108.4 ep len 200 avg score 11.5 avg_score_100 29.2 std score 21.0
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  303 score 114.3 ep len 200 avg score 11.8 avg_score_100 30.2 std score 21.7
# -----saving models------
# episode  304 score 127.2 ep len 200 avg score 12.2 avg_score_100 31.4 std score 22.7
# -----saving models------
# episode  305 score 130.2 ep len 200 avg score 12.6 avg_score_100 32.6 std score 23.6
# -----saving models------
# episode  306 score 131.4 ep len 200 avg score 12.9 avg_score_100 33.9 std score 24.5
# -----saving models------
# episode  307 score 126.0 ep len 200 avg score 13.3 avg_score_100 35.2 std score 25.3
# Target Updated
# Target Updated
# -----saving models------
# episode  308 score 133.1 ep len 200 avg score 13.7 avg_score_100 36.4 std score 26.2
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  309 score 136.1 ep len 200 avg score 14.1 avg_score_100 37.7 std score 27.0
# -----saving models------
# episode  310 score 134.9 ep len 200 avg score 14.5 avg_score_100 39.0 std score 27.9
# -----saving models------
# episode  311 score 140.3 ep len 200 avg score 14.9 avg_score_100 40.3 std score 28.7
# -----saving models------
# episode  312 score 132.4 ep len 200 avg score 15.3 avg_score_100 41.6 std score 29.4
# -----saving models------
# episode  313 score 29.6 ep len 39 avg score 15.3 avg_score_100 41.9 std score 29.4
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  314 score 141.9 ep len 200 avg score 15.7 avg_score_100 43.3 std score 30.2
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  315 score 139.4 ep len 200 avg score 16.1 avg_score_100 44.5 std score 30.9
# -----saving models------
# episode  316 score 122.9 ep len 172 avg score 16.4 avg_score_100 45.7 std score 31.5
# -----saving models------
# episode  317 score 132.7 ep len 200 avg score 16.8 avg_score_100 46.9 std score 32.1
# -----saving models------
# episode  318 score 137.7 ep len 200 avg score 17.2 avg_score_100 48.1 std score 32.7
# -----saving models------
# episode  319 score 137.9 ep len 200 avg score 17.6 avg_score_100 49.4 std score 33.4
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  320 score 146.7 ep len 200 avg score 18.0 avg_score_100 50.8 std score 34.1
# -----saving models------
# episode  321 score 143.3 ep len 200 avg score 18.3 avg_score_100 52.2 std score 34.7
# -----saving models------
# episode  322 score 148.7 ep len 200 avg score 18.8 avg_score_100 53.5 std score 35.4
# -----saving models------
# episode  323 score 37.3 ep len 55 avg score 18.8 avg_score_100 53.8 std score 35.4
# -----saving models------
# episode  324 score 48.3 ep len 65 avg score 18.9 avg_score_100 54.3 std score 35.4
# -----saving models------
# episode  325 score 156.3 ep len 200 avg score 19.3 avg_score_100 55.8 std score 36.1
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  326 score 140.7 ep len 200 avg score 19.7 avg_score_100 57.1 std score 36.7
# -----saving models------
# episode  327 score 146.9 ep len 200 avg score 20.1 avg_score_100 58.5 std score 37.3
# -----saving models------
# episode  328 score 145.5 ep len 200 avg score 20.5 avg_score_100 59.9 std score 37.9
# -----saving models------
# episode  329 score 148.6 ep len 200 avg score 20.8 avg_score_100 61.3 std score 38.5
# -----saving models------
# episode  330 score 142.6 ep len 200 avg score 21.2 avg_score_100 62.7 std score 39.0
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  331 score 148.5 ep len 200 avg score 21.6 avg_score_100 64.1 std score 39.6
# -----saving models------
# episode  332 score 155.5 ep len 200 avg score 22.0 avg_score_100 65.4 std score 40.2
# -----saving models------
# episode  333 score 135.2 ep len 200 avg score 22.3 avg_score_100 66.7 std score 40.6
# -----saving models------
# episode  334 score 149.6 ep len 200 avg score 22.7 avg_score_100 68.1 std score 41.1
# -----saving models------
# episode  335 score 147.3 ep len 200 avg score 23.1 avg_score_100 69.5 std score 41.6
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  336 score 154.2 ep len 200 avg score 23.5 avg_score_100 70.9 std score 42.2
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  337 score 144.1 ep len 200 avg score 23.8 avg_score_100 72.3 std score 42.6
# -----saving models------
# episode  338 score 152.4 ep len 200 avg score 24.2 avg_score_100 73.6 std score 43.1
# -----saving models------
# episode  339 score 143.1 ep len 200 avg score 24.6 avg_score_100 75.0 std score 43.5
# -----saving models------
# episode  340 score 150.5 ep len 200 avg score 24.9 avg_score_100 76.3 std score 44.0
# -----saving models------
# episode  341 score 151.1 ep len 200 avg score 25.3 avg_score_100 77.7 std score 44.4
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  342 score 153.6 ep len 200 avg score 25.7 avg_score_100 79.2 std score 44.9
# -----saving models------
# episode  343 score 149.3 ep len 200 avg score 26.0 avg_score_100 80.5 std score 45.3
# -----saving models------
# episode  344 score 156.8 ep len 200 avg score 26.4 avg_score_100 82.0 std score 45.8
# -----saving models------
# episode  345 score 148.0 ep len 200 avg score 26.8 avg_score_100 83.4 std score 46.2
# -----saving models------
# episode  346 score 155.2 ep len 200 avg score 27.1 avg_score_100 84.8 std score 46.7
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  347 score 159.7 ep len 200 avg score 27.5 avg_score_100 86.4 std score 47.1
# -----saving models------
# episode  348 score 160.7 ep len 200 avg score 27.9 avg_score_100 87.9 std score 47.6
# -----saving models------
# episode  349 score 150.3 ep len 200 avg score 28.3 avg_score_100 89.2 std score 48.0
# -----saving models------
# episode  350 score 152.5 ep len 200 avg score 28.6 avg_score_100 90.6 std score 48.4
# -----saving models------
# episode  351 score 149.0 ep len 200 avg score 28.9 avg_score_100 91.9 std score 48.7
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  352 score 144.7 ep len 200 avg score 29.3 avg_score_100 93.3 std score 49.0
# -----saving models------
# episode  353 score 162.2 ep len 200 avg score 29.6 avg_score_100 94.8 std score 49.5
# -----saving models------
# episode  354 score 150.3 ep len 200 avg score 30.0 avg_score_100 96.1 std score 49.8
# -----saving models------
# episode  355 score 153.9 ep len 200 avg score 30.3 avg_score_100 97.4 std score 50.2
# -----saving models------
# episode  356 score 161.2 ep len 200 avg score 30.7 avg_score_100 98.9 std score 50.6
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  357 score 150.8 ep len 200 avg score 31.0 avg_score_100 100.1 std score 50.9
# -----saving models------
# episode  358 score 159.2 ep len 200 avg score 31.4 avg_score_100 101.4 std score 51.3
# -----saving models------
# episode  359 score 151.1 ep len 200 avg score 31.7 avg_score_100 102.7 std score 51.6
# -----saving models------
# episode  360 score 155.4 ep len 200 avg score 32.1 avg_score_100 104.2 std score 51.9
# -----saving models------
# episode  361 score 147.4 ep len 200 avg score 32.4 avg_score_100 105.5 std score 52.2
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  362 score 150.4 ep len 200 avg score 32.7 avg_score_100 106.8 std score 52.5
# -----saving models------
# episode  363 score 164.1 ep len 200 avg score 33.1 avg_score_100 108.0 std score 52.9
# -----saving models------
# episode  364 score 154.8 ep len 200 avg score 33.4 avg_score_100 109.3 std score 53.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/o/Documents/thesis/ddqn_her/main.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/ddqn_her/main.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a>         done = True
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/ddqn_her/main.ipynb#W3sZmlsZQ%3D%3D?line=26'>27</a>     agent.remember(state=observation, action=action_index, done=done,
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/ddqn_her/main.ipynb#W3sZmlsZQ%3D%3D?line=27'>28</a>                     reward=reward, new_state=new_observation)
# ---> <a href='vscode-notebook-cell:/home/o/Documents/thesis/ddqn_her/main.ipynb#W3sZmlsZQ%3D%3D?line=28'>29</a>     agent.train()
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/ddqn_her/main.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a>     observation = new_observation
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/ddqn_her/main.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a> episode_lens.append(episode_len)
#
# File ~/Documents/thesis/ddqn_her/ddqn.py:119, in DDQNAgent.train(self)
#     116 target_old = np.array(q_pred)
#     118 #* get the q values of next states by target network
# --> 119 q_next = self.q_target.predict(new_state, verbose=0) # type: ignore #! target_val
#     121 #* get the q values of next states by main network
#     122 q_eval = self.q_eval.predict(new_state, verbose=0) # type: ignore #! target_next
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py:2596, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2587     except ValueError:
#    2588         warnings.warn(
#    2589             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2590             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2593             stacklevel=2,
#    2594         )
# -> 2596 data_handler = data_adapter.get_data_handler(
#    2597     x=x,
#    2598     batch_size=batch_size,
#    2599     steps_per_epoch=steps,
#    2600     initial_epoch=0,
#    2601     epochs=1,
#    2602     max_queue_size=max_queue_size,
#    2603     workers=workers,
#    2604     use_multiprocessing=use_multiprocessing,
#    2605     model=self,
#    2606     steps_per_execution=self._steps_per_execution,
#    2607 )
#    2609 # Container that configures and calls `tf.keras.Callback`s.
#    2610 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/data_adapter.py:1688, in get_data_handler(*args, **kwargs)
#    1686         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688 return DataHandler(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/data_adapter.py:1292, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1289     self._steps_per_execution = steps_per_execution
#    1291 adapter_cls = select_data_adapter(x, y)
# -> 1292 self._adapter = adapter_cls(
#    1293     x,
#    1294     y,
#    1295     batch_size=batch_size,
#    1296     steps=steps_per_epoch,
#    1297     epochs=epochs - initial_epoch,
#    1298     sample_weights=sample_weight,
#    1299     shuffle=shuffle,
#    1300     max_queue_size=max_queue_size,
#    1301     workers=workers,
#    1302     use_multiprocessing=use_multiprocessing,
#    1303     distribution_strategy=tf.distribute.get_strategy(),
#    1304     model=model,
#    1305     pss_evaluation_shards=pss_evaluation_shards,
#    1306 )
#    1308 strategy = tf.distribute.get_strategy()
#    1310 self._current_step = 0
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/data_adapter.py:353, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     350         flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     351     return flat_dataset
# --> 353 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     355 dataset = self.slice_inputs(indices_dataset, inputs)
#     357 if shuffle == "batch":
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:2313, in DatasetV2.flat_map(self, map_func, name)
#    2309 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2310 # dataset_ops).
#    2311 # pylint: disable=g-import-not-at-top,protected-access
#    2312 from tensorflow.python.data.ops import flat_map_op
# -> 2313 return flat_map_op._flat_map(self, map_func, name=name)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/data/ops/flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/data/ops/flat_map_op.py:33, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      30 def __init__(self, input_dataset, map_func, name=None):
#      32   self._input_dataset = input_dataset
# ---> 33   self._map_func = structured_function.StructuredFunctionWrapper(
#      34       map_func, self._transformation_name(), dataset=input_dataset)
#      35   if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#      36     raise TypeError(
#      37         "The `map_func` argument must return a `Dataset` object. Got "
#      38         f"{dataset_ops.get_type(self._map_func.output_structure)!r}.")
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/data/ops/structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1222, in Function.get_concrete_function(self, *args, **kwargs)
#    1220 def get_concrete_function(self, *args, **kwargs):
#    1221   # Implements GenericFunction.get_concrete_function.
# -> 1222   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1223   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1224   return concrete
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1192, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1190   if self._variable_creation_config is None:
#    1191     initializers = []
# -> 1192     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1193     self._initialize_uninitialized_variables(initializers)
#    1195 if self._created_variables:
#    1196   # In this case we have created variables on the first call, so we run the
#    1197   # version which is guaranteed to never create variables.
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:694, in Function._initialize(self, args, kwds, add_initializers_to)
#     689 self._variable_creation_config = self._generate_scoped_tracing_options(
#     690     variable_capturing_scope,
#     691     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     692 )
#     693 # Force the definition of the function for these arguments
# --> 694 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     695     args, kwds, self._variable_creation_config
#     696 )
#     698 def invalid_creator_scope(*unused_args, **unused_kwds):
#     699   """Disables variable creation."""
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     181   _set_arg_keywords(concrete_function)
#     183 if not tracing_options.bind_graph_to_function:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:284, in _maybe_define_function(args, kwargs, tracing_options)
#     282 else:
#     283   target_func_type = lookup_func_type
# --> 284 concrete_function = _create_concrete_function(
#     285     target_func_type, lookup_func_context, func_graph, tracing_options
#     286 )
#     288 if tracing_options.function_cache is not None:
#     289   tracing_options.function_cache.add(
#     290       concrete_function, current_func_context
#     291   )
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:308, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303 with func_graph.as_default():
#     304   placeholder_bound_args = function_type.placeholder_arguments(
#     305       placeholder_context
#     306   )
# --> 308 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     309     tracing_options.name,
#     310     tracing_options.python_function,
#     311     placeholder_bound_args.args,
#     312     placeholder_bound_args.kwargs,
#     313     None,
#     314     func_graph=func_graph,
#     315     arg_names=function_type_utils.to_arg_names(function_type),
#     316     create_placeholders=False,
#     317 )
#     319 transform.apply_func_graph_transforms(traced_func_graph)
#     321 graph_capture_container = traced_func_graph.function_captures
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:987, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#     984 else:
#     985   deps_control_manager = ops.NullContextmanager()
# --> 987 with func_graph.as_default(), deps_control_manager as deps_ctx:
#     988   current_scope = variable_scope.get_variable_scope()
#     989   default_use_resource = current_scope.use_resource
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/framework/auto_control_deps.py:428, in AutomaticControlDependencies.__exit__(self, unused_type, unused_value, unused_traceback)
#     421   continue
#     423 # Ensure stateful ops run.
#     424 # Read-only ops are added to control outputs if the read value is
#     425 # consumed. This covers the case when the read value is returned from
#     426 # the function since that goes through a tf.identity in mark_as_return.
#     427 if ((op_def_registry.get(op.type) is None) or
# --> 428     (op_is_stateful(op) and
#     429      (op.type not in utils.RESOURCE_READ_OPS or
#     430       any(output.consumers() for output in op.outputs)))):
#     431   ops_which_must_run.add(op)
#     433 # Make a note of all opened manager_ids.
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/framework/auto_control_deps.py:144, in op_is_stateful(op)
#     128 # LINT.ThenChange(//tensorflow/core/grappler/optimizers/function_optimizer.cc)
#     129
#     130 # Op types that are marked as stateless, but should be allowlisted to add auto
#     131 # control dependencies.
#     132 _ALLOWLIST_STATELESS_OPS = [
#     133     # As TPU collective ops are blocking, if there are more than one collective
#     134     # op in the function, we need to make sure different collectives ops are
#    (...)
#     140     "CollectivePermute",
#     141 ]
# --> 144 def op_is_stateful(op):
#     145   # pylint: disable=protected-access
#     146   ret = ((op._is_stateful and
#     147           ((op.type not in ASYNC_STATEFUL_OPS) and
#     148            (op.type not in LEGACY_RANDOM_OPS) and
#     149            (op.type not in SKIPPED_ORDER_INSENSITIVE_STATEFUL_OPS))) or
#     150          (op.type in _ALLOWLIST_STATELESS_OPS))
#     151   return ret
#
# KeyboardInterrupt:

# %%
n_steps = sum(episode_lens)
print(n_steps)
# Out:
# 20972

# %%
# env = record_videos(env)
from gymnasium.wrappers import RecordVideo

data = load_config()
env = gym.make('racetrack-v0', render_mode = 'rgb_array')
env.configure(data) # type: ignore

env = RecordVideo(env, video_folder="videos", episode_trigger=lambda e: True)
env.unwrapped.set_record_video_wrapper(env)

# main loop
for episode in trange(1, desc='Test episodes'):

        proc.reset()
        (observation, info), done = env.reset(), False
        truncated = False
        proc.update_input(observation, info)
        observation = proc.get_input()

        episode_reward = 0
        episode_len = 0

        while (not done) or truncated:
            
            action, action_index = agent.get_action(observation, deterministic=True)
            new_observation, reward, done, truncated, new_info = env.step(action=[action])
            
            proc.update_input(new_observation, info)
            new_observation = proc.get_input()

            episode_reward += reward # type: ignore
            episode_len +=1

            if new_info["rewards"]["on_road_reward"] == False or episode_len >=150:
               done = True
            
            observation = new_observation

        print('episode ', episode, 'score %.1f' % episode_reward, 'ep len', episode_len)   

env.close()
# Out:
# /home/o/Documents/thesis/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.configure to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.configure` for environment variables or `env.get_wrapper_attr('configure')` that will search the reminding wrappers.
#   logger.warn(
# /home/o/Documents/thesis/.venv/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /home/o/Documents/thesis/ddqn_her/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Test episodes:   0%|          | 0/1 [00:00<?, ?it/s]
# episode  0 score 122.4 ep len 150
# Moviepy - Building video /home/o/Documents/thesis/ddqn_her/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /home/o/Documents/thesis/ddqn_her/videos/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /home/o/Documents/thesis/ddqn_her/videos/rl-video-episode-0.mp4
