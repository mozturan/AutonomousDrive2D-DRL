# %%
# fundemental modules
import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
import time
import pprint
from tqdm.notebook import trange

from ddqn import DDQNAgent # type: ignore
from utils import load_config
from obs import observation_shape

aggregate_stats_every=100
best_score = -1000.0
score_history = []
episode_lens = []
avg_history = []
std_history = []
avg_history_100 = []
# Out:
# 2023-12-04 01:03:49.877537: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-04 01:03:49.902127: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-04 01:03:49.902149: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-04 01:03:49.902166: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-04 01:03:49.907218: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = load_config()
env = gym.make('racetrack-v0', render_mode = 'rgb_array')
env.configure(data) # type: ignore
# pprint.pprint(env.config) # type: ignore
(obs, info), done = env.reset(), False

#observation config
proc = observation_shape(obs,info,2)
proc.reset()
input = proc.get_input()
print(input.shape)
# Out:
# (26,)
# /home/o/Documents/thesis/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.configure to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.configure` for environment variables or `env.get_wrapper_attr('configure')` that will search the reminding wrappers.
#   logger.warn(

# %%
agent = DDQNAgent(alpha=0.001, gamma=0.9, epsilon=1.0, obs_shape=input.shape,
                  batch_size=64, epsilon_dec=0.9995, epsilon_end=0.05, mem_size=100000,
                  min_mem_size=100, replace_target=1000, learning_rate=0.0003)
print("Agent is initialized.")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               3456
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 21387 (83.54 KB)
# Trainable params: 21387 (83.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# summary
# Agent is initialized.
# 2023-12-04 01:03:59.882648: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 01:03:59.904053: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 01:03:59.904162: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 01:03:59.904974: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 01:03:59.905051: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 01:03:59.905098: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 01:04:00.252409: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 01:04:00.252503: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 01:04:00.252564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 01:04:00.252610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9734 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# main loop
for episode in trange(500, desc='Test episodes'):

        proc.reset()
        (observation, info), done = env.reset(), False
        truncated = False
        proc.update_input(observation, info)
        observation = proc.get_input()

        episode_reward = 0
        episode_len = 0

        while (not done) and (not truncated):
            
            action, action_index = agent.get_action(observation, deterministic=False)
            new_observation, reward, done, truncated, new_info = env.step(action=[action])
            
            proc.update_input(new_observation, info)
            new_observation = proc.get_input()

            episode_reward += reward # type: ignore
            episode_len +=1

            if new_info["rewards"]["on_road_reward"] == False or episode_len >= 200:
                done = True
            
            agent.remember(state=observation, action=action_index, done=done,
                            reward=reward, new_state=new_observation)
            agent.train()

            observation = new_observation

        episode_lens.append(episode_len)

        score_history.append(episode_reward)
        avg_score = np.mean(score_history)
        avg_history.append(avg_score)
        std_score = np.std(score_history)
        std_history.append(std_score)

        avg_score_100 = np.mean(score_history[-100:])
        avg_history_100.append(avg_score_100)

        if avg_score_100 > best_score:
            best_score = avg_score
            agent.save_model(episode)

        agent.tensorboard.update_stats(episode_rew = episode_reward,
                                       average_rew =avg_score,
                                       average_100_reward = avg_score_100,
                                       std_rew=std_score,
                                       epsilon=agent.epsilon,
                                       episode_len = episode_len)
        

        print('episode ', episode, 'score %.1f' % episode_reward, 'ep len', episode_len,
              'avg score %.1f' % avg_score, 'avg_score_100 %.1f' %avg_score_100,'std score %.1f' % std_score)
# Out:
# Test episodes:   0%|          | 0/500 [00:00<?, ?it/s]
# -----saving models------
# 2023-12-04 01:04:04.239403: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# episode  0 score -0.4 ep len 3 avg score -0.4 avg_score_100 -0.4 std score 0.0
# -----saving models------
# episode  1 score 0.7 ep len 10 avg score 0.2 avg_score_100 0.2 std score 0.6
# -----saving models------
# episode  2 score 1.6 ep len 21 avg score 0.6 avg_score_100 0.6 std score 0.8
# episode  3 score -0.4 ep len 6 avg score 0.4 avg_score_100 0.4 std score 0.8
# episode  4 score 0.0 ep len 7 avg score 0.3 avg_score_100 0.3 std score 0.8
# episode  5 score 0.2 ep len 9 avg score 0.3 avg_score_100 0.3 std score 0.7
# episode  6 score -2.2 ep len 19 avg score -0.1 avg_score_100 -0.1 std score 1.1
# episode  7 score -0.3 ep len 2 avg score -0.1 avg_score_100 -0.1 std score 1.0
# episode  8 score -0.1 ep len 5 avg score -0.1 avg_score_100 -0.1 std score 0.9
# episode  9 score -0.3 ep len 6 avg score -0.1 avg_score_100 -0.1 std score 0.9
# episode  10 score 0.8 ep len 9 avg score -0.0 avg_score_100 -0.0 std score 0.9
# 2023-12-04 01:04:06.252625: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f36a0150b80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-04 01:04:06.252641: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2023-12-04 01:04:06.255608: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-04 01:04:07.164155: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8902
# 2023-12-04 01:04:07.218801: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# episode  11 score 0.0 ep len 4 avg score -0.0 avg_score_100 -0.0 std score 0.9
# episode  12 score -0.3 ep len 7 avg score -0.0 avg_score_100 -0.0 std score 0.8
# episode  13 score 2.3 ep len 12 avg score 0.1 avg_score_100 0.1 std score 1.0
# episode  14 score -0.2 ep len 25 avg score 0.1 avg_score_100 0.1 std score 1.0
# episode  15 score 0.6 ep len 7 avg score 0.1 avg_score_100 0.1 std score 1.0
# episode  16 score -1.9 ep len 19 avg score 0.0 avg_score_100 0.0 std score 1.0
# episode  17 score 0.7 ep len 6 avg score 0.1 avg_score_100 0.1 std score 1.0
# episode  18 score 2.0 ep len 12 avg score 0.2 avg_score_100 0.2 std score 1.1
# episode  19 score -0.9 ep len 9 avg score 0.1 avg_score_100 0.1 std score 1.1
# episode  20 score 2.3 ep len 8 avg score 0.2 avg_score_100 0.2 std score 1.1
# episode  21 score 1.2 ep len 25 avg score 0.3 avg_score_100 0.3 std score 1.1
# episode  22 score 0.4 ep len 8 avg score 0.3 avg_score_100 0.3 std score 1.1
# episode  23 score 0.0 ep len 7 avg score 0.3 avg_score_100 0.3 std score 1.1
# episode  24 score 0.6 ep len 7 avg score 0.3 avg_score_100 0.3 std score 1.1
# episode  25 score 2.5 ep len 6 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  26 score 1.2 ep len 7 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  27 score -0.4 ep len 8 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  28 score 0.2 ep len 20 avg score 0.3 avg_score_100 0.3 std score 1.1
# episode  29 score 1.0 ep len 11 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  30 score 1.0 ep len 10 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  31 score -0.3 ep len 5 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  32 score 0.5 ep len 5 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  33 score -0.7 ep len 13 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  34 score -0.7 ep len 9 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  35 score -0.2 ep len 3 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  36 score 0.1 ep len 20 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  37 score -0.2 ep len 4 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  38 score 0.4 ep len 14 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  39 score -0.2 ep len 3 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  40 score -0.1 ep len 3 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  41 score -0.3 ep len 3 avg score 0.2 avg_score_100 0.2 std score 1.0
# episode  42 score 0.8 ep len 6 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  43 score 0.3 ep len 10 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  44 score 0.4 ep len 12 avg score 0.3 avg_score_100 0.3 std score 0.9
# episode  45 score -1.8 ep len 22 avg score 0.2 avg_score_100 0.2 std score 1.0
# episode  46 score 0.9 ep len 18 avg score 0.2 avg_score_100 0.2 std score 1.0
# episode  47 score 0.2 ep len 11 avg score 0.2 avg_score_100 0.2 std score 1.0
# episode  48 score -0.3 ep len 9 avg score 0.2 avg_score_100 0.2 std score 1.0
# episode  49 score 0.8 ep len 5 avg score 0.2 avg_score_100 0.2 std score 1.0
# episode  50 score 2.4 ep len 24 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  51 score -0.4 ep len 4 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  52 score 2.0 ep len 13 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  53 score 0.2 ep len 6 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  54 score 1.6 ep len 14 avg score 0.3 avg_score_100 0.3 std score 1.0
# episode  55 score 3.0 ep len 12 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  56 score 1.1 ep len 10 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  57 score 0.6 ep len 9 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  58 score 2.0 ep len 20 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  59 score -0.3 ep len 5 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  60 score 0.0 ep len 7 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  61 score 0.7 ep len 9 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  62 score -0.4 ep len 6 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  63 score -0.1 ep len 3 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  64 score 2.4 ep len 7 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  65 score 2.4 ep len 24 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  66 score -1.2 ep len 14 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  67 score -0.4 ep len 16 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  68 score 0.1 ep len 7 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  69 score -0.1 ep len 6 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  70 score -0.1 ep len 4 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  71 score 1.3 ep len 9 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  72 score 1.5 ep len 9 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  73 score 0.7 ep len 4 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  74 score 0.8 ep len 8 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  75 score -0.1 ep len 13 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  76 score 0.9 ep len 17 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  77 score -0.0 ep len 4 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  78 score -0.6 ep len 7 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  79 score 0.6 ep len 7 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  80 score -1.6 ep len 22 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  81 score -0.2 ep len 20 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  82 score 2.7 ep len 5 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  83 score 1.1 ep len 13 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  84 score -0.1 ep len 4 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  85 score -0.7 ep len 10 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  86 score -0.1 ep len 4 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  87 score -0.2 ep len 3 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  88 score -0.2 ep len 8 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  89 score 0.5 ep len 4 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  90 score 1.5 ep len 21 avg score 0.4 avg_score_100 0.4 std score 1.0
# episode  91 score 3.5 ep len 17 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  92 score 0.2 ep len 11 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  93 score -0.4 ep len 11 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  94 score 0.6 ep len 4 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  95 score -0.7 ep len 7 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  96 score 3.9 ep len 17 avg score 0.4 avg_score_100 0.4 std score 1.1
# episode  97 score 2.5 ep len 6 avg score 0.5 avg_score_100 0.5 std score 1.1
# episode  98 score 2.0 ep len 21 avg score 0.5 avg_score_100 0.5 std score 1.1
# episode  99 score 1.3 ep len 26 avg score 0.5 avg_score_100 0.5 std score 1.1
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# episode  100 score -0.3 ep len 10 avg score 0.5 avg_score_100 0.5 std score 1.1
# episode  101 score -0.4 ep len 4 avg score 0.5 avg_score_100 0.5 std score 1.1
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# episode  102 score 1.0 ep len 11 avg score 0.5 avg_score_100 0.5 std score 1.1
# episode  103 score 1.8 ep len 5 avg score 0.5 avg_score_100 0.5 std score 1.1
# episode  104 score 3.8 ep len 10 avg score 0.5 avg_score_100 0.5 std score 1.2
# episode  105 score -1.0 ep len 15 avg score 0.5 avg_score_100 0.5 std score 1.2
# episode  106 score 1.8 ep len 8 avg score 0.5 avg_score_100 0.5 std score 1.2
# episode  107 score -0.3 ep len 3 avg score 0.5 avg_score_100 0.5 std score 1.2
# episode  108 score 2.8 ep len 8 avg score 0.5 avg_score_100 0.6 std score 1.2
# episode  109 score -0.4 ep len 11 avg score 0.5 avg_score_100 0.6 std score 1.2
# episode  110 score -0.5 ep len 4 avg score 0.5 avg_score_100 0.6 std score 1.2
# episode  111 score -0.5 ep len 7 avg score 0.5 avg_score_100 0.6 std score 1.2
# episode  112 score -0.4 ep len 8 avg score 0.5 avg_score_100 0.6 std score 1.2
# episode  113 score 3.5 ep len 10 avg score 0.5 avg_score_100 0.6 std score 1.2
# episode  114 score 2.2 ep len 8 avg score 0.5 avg_score_100 0.6 std score 1.2
# -----saving models------
# episode  115 score 5.4 ep len 13 avg score 0.6 avg_score_100 0.6 std score 1.3
# -----saving models------
# episode  116 score -2.0 ep len 22 avg score 0.5 avg_score_100 0.6 std score 1.3
# -----saving models------
# episode  117 score -0.4 ep len 6 avg score 0.5 avg_score_100 0.6 std score 1.3
# -----saving models------
# episode  118 score 0.7 ep len 4 avg score 0.5 avg_score_100 0.6 std score 1.3
# -----saving models------
# episode  119 score -0.3 ep len 3 avg score 0.5 avg_score_100 0.6 std score 1.3
# -----saving models------
# episode  120 score 4.0 ep len 15 avg score 0.6 avg_score_100 0.6 std score 1.3
# -----saving models------
# episode  121 score -0.3 ep len 4 avg score 0.6 avg_score_100 0.6 std score 1.3
# -----saving models------
# episode  122 score -0.2 ep len 4 avg score 0.5 avg_score_100 0.6 std score 1.3
# -----saving models------
# episode  123 score 4.0 ep len 14 avg score 0.6 avg_score_100 0.7 std score 1.3
# -----saving models------
# episode  124 score 1.8 ep len 9 avg score 0.6 avg_score_100 0.7 std score 1.3
# -----saving models------
# episode  125 score 2.9 ep len 11 avg score 0.6 avg_score_100 0.7 std score 1.4
# -----saving models------
# episode  126 score -0.7 ep len 21 avg score 0.6 avg_score_100 0.7 std score 1.4
# -----saving models------
# episode  127 score 2.3 ep len 7 avg score 0.6 avg_score_100 0.7 std score 1.4
# -----saving models------
# episode  128 score -0.2 ep len 3 avg score 0.6 avg_score_100 0.7 std score 1.4
# -----saving models------
# episode  129 score 3.6 ep len 16 avg score 0.6 avg_score_100 0.7 std score 1.4
# -----saving models------
# episode  130 score 3.5 ep len 18 avg score 0.6 avg_score_100 0.7 std score 1.4
# -----saving models------
# episode  131 score 1.1 ep len 5 avg score 0.7 avg_score_100 0.7 std score 1.4
# -----saving models------
# episode  132 score 3.4 ep len 8 avg score 0.7 avg_score_100 0.8 std score 1.4
# -----saving models------
# episode  133 score 1.4 ep len 6 avg score 0.7 avg_score_100 0.8 std score 1.4
# -----saving models------
# episode  134 score -0.1 ep len 14 avg score 0.7 avg_score_100 0.8 std score 1.4
# -----saving models------
# episode  135 score 0.5 ep len 8 avg score 0.7 avg_score_100 0.8 std score 1.4
# -----saving models------
# episode  136 score 3.1 ep len 22 avg score 0.7 avg_score_100 0.8 std score 1.4
# -----saving models------
# episode  137 score 1.3 ep len 15 avg score 0.7 avg_score_100 0.8 std score 1.4
# -----saving models------
# episode  138 score 1.1 ep len 5 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  139 score 1.1 ep len 6 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  140 score 0.6 ep len 18 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  141 score 0.8 ep len 8 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  142 score -0.2 ep len 17 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  143 score 0.5 ep len 17 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  144 score 1.7 ep len 7 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  145 score -0.1 ep len 4 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  146 score 1.9 ep len 16 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  147 score 0.4 ep len 9 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  148 score 0.4 ep len 8 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  149 score 1.5 ep len 10 avg score 0.7 avg_score_100 0.9 std score 1.4
# -----saving models------
# episode  150 score 4.3 ep len 17 avg score 0.7 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  151 score 0.3 ep len 5 avg score 0.7 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  152 score 2.2 ep len 6 avg score 0.7 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  153 score 3.1 ep len 10 avg score 0.7 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  154 score -0.2 ep len 4 avg score 0.7 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  155 score 5.5 ep len 15 avg score 0.8 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  156 score 0.7 ep len 5 avg score 0.8 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  157 score 1.5 ep len 12 avg score 0.8 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  158 score 1.3 ep len 22 avg score 0.8 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  159 score -0.2 ep len 6 avg score 0.8 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  160 score 2.4 ep len 13 avg score 0.8 avg_score_100 1.0 std score 1.4
# -----saving models------
# episode  161 score 7.4 ep len 15 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  162 score -0.3 ep len 4 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  163 score 1.4 ep len 6 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  164 score 1.7 ep len 5 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  165 score -0.2 ep len 23 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  166 score 0.7 ep len 3 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  167 score 2.6 ep len 28 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  168 score 1.6 ep len 15 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  169 score -0.9 ep len 12 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  170 score -0.6 ep len 6 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  171 score 2.0 ep len 12 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  172 score 1.0 ep len 8 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  173 score 1.8 ep len 7 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  174 score 0.2 ep len 4 avg score 0.8 avg_score_100 1.1 std score 1.5
# -----saving models------
# episode  175 score 3.7 ep len 8 avg score 0.8 avg_score_100 1.2 std score 1.5
# -----saving models------
# episode  176 score 6.6 ep len 12 avg score 0.9 avg_score_100 1.2 std score 1.5
# -----saving models------
# episode  177 score -0.3 ep len 4 avg score 0.9 avg_score_100 1.2 std score 1.5
# -----saving models------
# episode  178 score -0.3 ep len 4 avg score 0.9 avg_score_100 1.2 std score 1.5
# -----saving models------
# episode  179 score 0.4 ep len 6 avg score 0.9 avg_score_100 1.2 std score 1.5
# -----saving models------
# episode  180 score 3.1 ep len 12 avg score 0.9 avg_score_100 1.3 std score 1.5
# -----saving models------
# episode  181 score -0.5 ep len 10 avg score 0.9 avg_score_100 1.3 std score 1.5
# -----saving models------
# episode  182 score 4.2 ep len 26 avg score 0.9 avg_score_100 1.3 std score 1.6
# -----saving models------
# episode  183 score 1.8 ep len 15 avg score 0.9 avg_score_100 1.3 std score 1.6
# -----saving models------
# episode  184 score 5.4 ep len 9 avg score 0.9 avg_score_100 1.3 std score 1.6
# -----saving models------
# episode  185 score 1.8 ep len 13 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  186 score 5.6 ep len 12 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  187 score -0.2 ep len 24 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  188 score -0.8 ep len 7 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  189 score 1.8 ep len 6 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  190 score 2.9 ep len 8 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  191 score 0.1 ep len 19 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  192 score 1.0 ep len 6 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  193 score 1.2 ep len 22 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  194 score 1.3 ep len 18 avg score 0.9 avg_score_100 1.4 std score 1.6
# -----saving models------
# episode  195 score 0.4 ep len 6 avg score 0.9 avg_score_100 1.5 std score 1.6
# -----saving models------
# episode  196 score 5.0 ep len 9 avg score 1.0 avg_score_100 1.5 std score 1.6
# -----saving models------
# episode  197 score 2.4 ep len 7 avg score 1.0 avg_score_100 1.5 std score 1.6
# -----saving models------
# episode  198 score -0.3 ep len 3 avg score 1.0 avg_score_100 1.4 std score 1.6
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  199 score 4.1 ep len 17 avg score 1.0 avg_score_100 1.5 std score 1.6
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  200 score 0.8 ep len 5 avg score 1.0 avg_score_100 1.5 std score 1.6
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  201 score 14.3 ep len 29 avg score 1.0 avg_score_100 1.6 std score 1.9
# -----saving models------
# episode  202 score 10.7 ep len 17 avg score 1.1 avg_score_100 1.7 std score 2.0
# -----saving models------
# episode  203 score 3.3 ep len 16 avg score 1.1 avg_score_100 1.7 std score 2.0
# -----saving models------
# episode  204 score 4.2 ep len 27 avg score 1.1 avg_score_100 1.7 std score 2.0
# -----saving models------
# episode  205 score 3.0 ep len 16 avg score 1.1 avg_score_100 1.8 std score 2.0
# -----saving models------
# episode  206 score 0.0 ep len 6 avg score 1.1 avg_score_100 1.8 std score 2.0
# -----saving models------
# episode  207 score 2.5 ep len 14 avg score 1.1 avg_score_100 1.8 std score 2.0
# -----saving models------
# episode  208 score 10.2 ep len 19 avg score 1.2 avg_score_100 1.9 std score 2.1
# -----saving models------
# episode  209 score 0.5 ep len 6 avg score 1.2 avg_score_100 1.9 std score 2.1
# -----saving models------
# episode  210 score 7.0 ep len 18 avg score 1.2 avg_score_100 2.0 std score 2.1
# -----saving models------
# episode  211 score 3.9 ep len 12 avg score 1.2 avg_score_100 2.0 std score 2.1
# -----saving models------
# episode  212 score -0.1 ep len 7 avg score 1.2 avg_score_100 2.0 std score 2.1
# -----saving models------
# episode  213 score 12.4 ep len 19 avg score 1.3 avg_score_100 2.1 std score 2.2
# -----saving models------
# episode  214 score 6.0 ep len 13 avg score 1.3 avg_score_100 2.1 std score 2.2
# -----saving models------
# episode  215 score 5.8 ep len 45 avg score 1.3 avg_score_100 2.1 std score 2.3
# -----saving models------
# episode  216 score 0.8 ep len 5 avg score 1.3 avg_score_100 2.2 std score 2.3
# -----saving models------
# episode  217 score 3.0 ep len 9 avg score 1.3 avg_score_100 2.2 std score 2.3
# -----saving models------
# episode  218 score 2.0 ep len 6 avg score 1.3 avg_score_100 2.2 std score 2.3
# -----saving models------
# episode  219 score -0.6 ep len 34 avg score 1.3 avg_score_100 2.2 std score 2.2
# -----saving models------
# episode  220 score 2.9 ep len 15 avg score 1.3 avg_score_100 2.2 std score 2.2
# -----saving models------
# episode  221 score 8.5 ep len 26 avg score 1.3 avg_score_100 2.3 std score 2.3
# -----saving models------
# episode  222 score 2.8 ep len 7 avg score 1.3 avg_score_100 2.3 std score 2.3
# -----saving models------
# episode  223 score 2.9 ep len 15 avg score 1.3 avg_score_100 2.3 std score 2.3
# -----saving models------
# episode  224 score 7.1 ep len 31 avg score 1.4 avg_score_100 2.4 std score 2.3
# -----saving models------
# episode  225 score 1.9 ep len 20 avg score 1.4 avg_score_100 2.3 std score 2.3
# -----saving models------
# episode  226 score 0.3 ep len 26 avg score 1.4 avg_score_100 2.4 std score 2.3
# -----saving models------
# episode  227 score 1.3 ep len 21 avg score 1.4 avg_score_100 2.3 std score 2.3
# -----saving models------
# episode  228 score 5.0 ep len 16 avg score 1.4 avg_score_100 2.4 std score 2.3
# -----saving models------
# episode  229 score 5.2 ep len 14 avg score 1.4 avg_score_100 2.4 std score 2.3
# -----saving models------
# episode  230 score 4.0 ep len 20 avg score 1.4 avg_score_100 2.4 std score 2.3
# -----saving models------
# episode  231 score 5.1 ep len 21 avg score 1.4 avg_score_100 2.5 std score 2.3
# -----saving models------
# episode  232 score 7.3 ep len 18 avg score 1.5 avg_score_100 2.5 std score 2.4
# -----saving models------
# episode  233 score 3.6 ep len 11 avg score 1.5 avg_score_100 2.5 std score 2.4
# -----saving models------
# episode  234 score 1.8 ep len 5 avg score 1.5 avg_score_100 2.5 std score 2.3
# -----saving models------
# episode  235 score -0.4 ep len 4 avg score 1.5 avg_score_100 2.5 std score 2.3
# -----saving models------
# episode  236 score 0.3 ep len 10 avg score 1.5 avg_score_100 2.5 std score 2.3
# -----saving models------
# episode  237 score 2.7 ep len 17 avg score 1.5 avg_score_100 2.5 std score 2.3
# -----saving models------
# episode  238 score 8.5 ep len 25 avg score 1.5 avg_score_100 2.6 std score 2.4
# -----saving models------
# episode  239 score -0.6 ep len 20 avg score 1.5 avg_score_100 2.6 std score 2.4
# -----saving models------
# episode  240 score 0.4 ep len 6 avg score 1.5 avg_score_100 2.6 std score 2.4
# -----saving models------
# episode  241 score 7.7 ep len 13 avg score 1.5 avg_score_100 2.6 std score 2.4
# -----saving models------
# episode  242 score 4.5 ep len 21 avg score 1.5 avg_score_100 2.7 std score 2.4
# -----saving models------
# episode  243 score 8.7 ep len 44 avg score 1.5 avg_score_100 2.8 std score 2.4
# -----saving models------
# episode  244 score 2.6 ep len 26 avg score 1.5 avg_score_100 2.8 std score 2.4
# -----saving models------
# episode  245 score 7.3 ep len 28 avg score 1.6 avg_score_100 2.8 std score 2.5
# -----saving models------
# episode  246 score 6.8 ep len 25 avg score 1.6 avg_score_100 2.9 std score 2.5
# -----saving models------
# episode  247 score 3.4 ep len 18 avg score 1.6 avg_score_100 2.9 std score 2.5
# -----saving models------
# episode  248 score 2.0 ep len 12 avg score 1.6 avg_score_100 2.9 std score 2.5
# -----saving models------
# episode  249 score 5.4 ep len 9 avg score 1.6 avg_score_100 3.0 std score 2.5
# -----saving models------
# episode  250 score 4.4 ep len 9 avg score 1.6 avg_score_100 3.0 std score 2.5
# -----saving models------
# episode  251 score 7.3 ep len 27 avg score 1.6 avg_score_100 3.1 std score 2.5
# -----saving models------
# episode  252 score 5.2 ep len 8 avg score 1.7 avg_score_100 3.1 std score 2.5
# -----saving models------
# episode  253 score 3.2 ep len 23 avg score 1.7 avg_score_100 3.1 std score 2.5
# -----saving models------
# episode  254 score 5.5 ep len 16 avg score 1.7 avg_score_100 3.1 std score 2.5
# -----saving models------
# episode  255 score 10.4 ep len 39 avg score 1.7 avg_score_100 3.2 std score 2.6
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  256 score 2.7 ep len 26 avg score 1.7 avg_score_100 3.2 std score 2.6
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  257 score 6.0 ep len 39 avg score 1.7 avg_score_100 3.3 std score 2.6
# -----saving models------
# episode  258 score 3.3 ep len 34 avg score 1.7 avg_score_100 3.3 std score 2.6
# -----saving models------
# episode  259 score 2.7 ep len 23 avg score 1.7 avg_score_100 3.3 std score 2.6
# -----saving models------
# episode  260 score 2.3 ep len 28 avg score 1.7 avg_score_100 3.3 std score 2.6
# -----saving models------
# episode  261 score 5.2 ep len 17 avg score 1.8 avg_score_100 3.3 std score 2.6
# -----saving models------
# episode  262 score 4.4 ep len 17 avg score 1.8 avg_score_100 3.3 std score 2.6
# -----saving models------
# episode  263 score 9.7 ep len 16 avg score 1.8 avg_score_100 3.4 std score 2.6
# -----saving models------
# episode  264 score 8.5 ep len 46 avg score 1.8 avg_score_100 3.5 std score 2.6
# -----saving models------
# episode  265 score 4.7 ep len 19 avg score 1.8 avg_score_100 3.5 std score 2.6
# -----saving models------
# episode  266 score 7.2 ep len 23 avg score 1.9 avg_score_100 3.6 std score 2.6
# -----saving models------
# episode  267 score 1.3 ep len 6 avg score 1.9 avg_score_100 3.6 std score 2.6
# -----saving models------
# episode  268 score 5.3 ep len 26 avg score 1.9 avg_score_100 3.6 std score 2.6
# -----saving models------
# episode  269 score 6.6 ep len 19 avg score 1.9 avg_score_100 3.7 std score 2.6
# -----saving models------
# episode  270 score 10.7 ep len 74 avg score 1.9 avg_score_100 3.8 std score 2.7
# -----saving models------
# episode  271 score 0.6 ep len 56 avg score 1.9 avg_score_100 3.8 std score 2.7
# -----saving models------
# episode  272 score 3.6 ep len 44 avg score 1.9 avg_score_100 3.8 std score 2.7
# -----saving models------
# episode  273 score 5.6 ep len 9 avg score 1.9 avg_score_100 3.9 std score 2.7
# -----saving models------
# episode  274 score 5.3 ep len 18 avg score 1.9 avg_score_100 3.9 std score 2.7
# -----saving models------
# episode  275 score 6.6 ep len 16 avg score 2.0 avg_score_100 3.9 std score 2.7
# -----saving models------
# episode  276 score 4.6 ep len 22 avg score 2.0 avg_score_100 3.9 std score 2.7
# -----saving models------
# episode  277 score 8.4 ep len 26 avg score 2.0 avg_score_100 4.0 std score 2.7
# -----saving models------
# episode  278 score 6.2 ep len 36 avg score 2.0 avg_score_100 4.1 std score 2.7
# -----saving models------
# episode  279 score 17.7 ep len 56 avg score 2.1 avg_score_100 4.2 std score 2.9
# -----saving models------
# episode  280 score 6.8 ep len 20 avg score 2.1 avg_score_100 4.3 std score 2.9
# -----saving models------
# episode  281 score 9.8 ep len 24 avg score 2.1 avg_score_100 4.4 std score 2.9
# -----saving models------
# episode  282 score 13.5 ep len 36 avg score 2.2 avg_score_100 4.5 std score 3.0
# -----saving models------
# episode  283 score 8.8 ep len 57 avg score 2.2 avg_score_100 4.5 std score 3.0
# -----saving models------
# episode  284 score 3.0 ep len 21 avg score 2.2 avg_score_100 4.5 std score 3.0
# -----saving models------
# episode  285 score 21.9 ep len 78 avg score 2.2 avg_score_100 4.7 std score 3.2
# -----saving models------
# episode  286 score 10.2 ep len 24 avg score 2.3 avg_score_100 4.8 std score 3.3
# -----saving models------
# episode  287 score 14.2 ep len 53 avg score 2.3 avg_score_100 4.9 std score 3.3
# -----saving models------
# episode  288 score 9.9 ep len 29 avg score 2.3 avg_score_100 5.0 std score 3.4
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  289 score 4.2 ep len 66 avg score 2.3 avg_score_100 5.0 std score 3.3
# -----saving models------
# episode  290 score 9.8 ep len 27 avg score 2.4 avg_score_100 5.1 std score 3.4
# -----saving models------
# episode  291 score 11.6 ep len 62 avg score 2.4 avg_score_100 5.2 std score 3.4
# -----saving models------
# episode  292 score 11.9 ep len 58 avg score 2.4 avg_score_100 5.3 std score 3.4
# -----saving models------
# episode  293 score 15.9 ep len 54 avg score 2.5 avg_score_100 5.5 std score 3.5
# -----saving models------
# episode  294 score 16.2 ep len 45 avg score 2.5 avg_score_100 5.6 std score 3.6
# -----saving models------
# episode  295 score 17.9 ep len 85 avg score 2.6 avg_score_100 5.8 std score 3.7
# -----saving models------
# episode  296 score 14.8 ep len 21 avg score 2.6 avg_score_100 5.9 std score 3.8
# -----saving models------
# episode  297 score 16.1 ep len 29 avg score 2.7 avg_score_100 6.0 std score 3.8
# -----saving models------
# episode  298 score 24.1 ep len 48 avg score 2.7 avg_score_100 6.3 std score 4.0
# -----saving models------
# episode  299 score 15.3 ep len 42 avg score 2.8 avg_score_100 6.4 std score 4.1
# -----saving models------
# episode  300 score 10.8 ep len 25 avg score 2.8 avg_score_100 6.5 std score 4.1
# -----saving models------
# episode  301 score 14.6 ep len 57 avg score 2.8 avg_score_100 6.5 std score 4.2
# -----saving models------
# episode  302 score 22.0 ep len 76 avg score 2.9 avg_score_100 6.6 std score 4.3
# -----saving models------
# episode  303 score 15.3 ep len 33 avg score 3.0 avg_score_100 6.7 std score 4.3
# -----saving models------
# episode  304 score 23.9 ep len 70 avg score 3.0 avg_score_100 6.9 std score 4.5
# -----saving models------
# episode  305 score 20.3 ep len 86 avg score 3.1 avg_score_100 7.1 std score 4.6
# -----saving models------
# episode  306 score 19.0 ep len 60 avg score 3.1 avg_score_100 7.3 std score 4.7
# Target Updated
# -----saving models------
# episode  307 score 26.9 ep len 86 avg score 3.2 avg_score_100 7.5 std score 4.9
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  308 score 43.4 ep len 199 avg score 3.3 avg_score_100 7.9 std score 5.4
# -----saving models------
# episode  309 score 21.7 ep len 48 avg score 3.4 avg_score_100 8.1 std score 5.5
# -----saving models------
# episode  310 score 25.3 ep len 72 avg score 3.5 avg_score_100 8.3 std score 5.6
# -----saving models------
# episode  311 score 30.7 ep len 85 avg score 3.6 avg_score_100 8.5 std score 5.8
# -----saving models------
# episode  312 score 36.9 ep len 70 avg score 3.7 avg_score_100 8.9 std score 6.1
# -----saving models------
# episode  313 score 30.1 ep len 83 avg score 3.7 avg_score_100 9.1 std score 6.2
# -----saving models------
# episode  314 score 28.5 ep len 48 avg score 3.8 avg_score_100 9.3 std score 6.4
# -----saving models------
# episode  315 score 32.2 ep len 75 avg score 3.9 avg_score_100 9.6 std score 6.6
# -----saving models------
# episode  316 score 34.6 ep len 74 avg score 4.0 avg_score_100 9.9 std score 6.8
# -----saving models------
# episode  317 score 27.3 ep len 49 avg score 4.1 avg_score_100 10.1 std score 6.9
# -----saving models------
# episode  318 score 42.2 ep len 92 avg score 4.2 avg_score_100 10.6 std score 7.2
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  319 score 72.9 ep len 200 avg score 4.4 avg_score_100 11.3 std score 8.2
# -----saving models------
# episode  320 score 42.1 ep len 82 avg score 4.5 avg_score_100 11.7 std score 8.4
# -----saving models------
# episode  321 score 37.2 ep len 74 avg score 4.6 avg_score_100 12.0 std score 8.6
# -----saving models------
# episode  322 score 45.1 ep len 92 avg score 4.8 avg_score_100 12.4 std score 8.9
# -----saving models------
# episode  323 score 74.9 ep len 168 avg score 5.0 avg_score_100 13.1 std score 9.7
# -----saving models------
# episode  324 score 35.4 ep len 53 avg score 5.1 avg_score_100 13.4 std score 9.8
# -----saving models------
# episode  325 score 82.1 ep len 200 avg score 5.3 avg_score_100 14.2 std score 10.7
# -----saving models------
# episode  326 score 51.2 ep len 109 avg score 5.4 avg_score_100 14.7 std score 11.0
# -----saving models------
# episode  327 score 37.7 ep len 87 avg score 5.5 avg_score_100 15.1 std score 11.1
# -----saving models------
# episode  328 score 40.1 ep len 86 avg score 5.7 avg_score_100 15.4 std score 11.2
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  329 score 44.0 ep len 91 avg score 5.8 avg_score_100 15.8 std score 11.4
# -----saving models------
# episode  330 score 73.9 ep len 165 avg score 6.0 avg_score_100 16.5 std score 12.0
# -----saving models------
# episode  331 score 50.4 ep len 83 avg score 6.1 avg_score_100 17.0 std score 12.2
# -----saving models------
# episode  332 score 68.3 ep len 115 avg score 6.3 avg_score_100 17.6 std score 12.7
# -----saving models------
# episode  333 score 58.0 ep len 86 avg score 6.4 avg_score_100 18.1 std score 13.0
# -----saving models------
# episode  334 score 35.6 ep len 71 avg score 6.5 avg_score_100 18.4 std score 13.0
# -----saving models------
# episode  335 score 99.1 ep len 200 avg score 6.8 avg_score_100 19.4 std score 14.0
# -----saving models------
# episode  336 score 86.6 ep len 173 avg score 7.0 avg_score_100 20.3 std score 14.6
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  337 score 79.7 ep len 136 avg score 7.3 avg_score_100 21.1 std score 15.1
# -----saving models------
# episode  338 score 87.2 ep len 200 avg score 7.5 avg_score_100 21.9 std score 15.7
# -----saving models------
# episode  339 score 102.3 ep len 200 avg score 7.8 avg_score_100 22.9 std score 16.5
# -----saving models------
# episode  340 score 61.1 ep len 89 avg score 7.9 avg_score_100 23.5 std score 16.7
# -----saving models------
# episode  341 score 99.7 ep len 185 avg score 8.2 avg_score_100 24.4 std score 17.4
# -----saving models------
# episode  342 score 122.3 ep len 200 avg score 8.5 avg_score_100 25.6 std score 18.4
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  343 score 114.5 ep len 200 avg score 8.8 avg_score_100 26.7 std score 19.3
# -----saving models------
# episode  344 score 105.4 ep len 144 avg score 9.1 avg_score_100 27.7 std score 19.9
# -----saving models------
# episode  345 score 104.7 ep len 200 avg score 9.4 avg_score_100 28.7 std score 20.6
# -----saving models------
# episode  346 score 119.4 ep len 200 avg score 9.7 avg_score_100 29.8 std score 21.4
# -----saving models------
# episode  347 score 119.3 ep len 200 avg score 10.0 avg_score_100 30.9 std score 22.1
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  348 score 108.8 ep len 200 avg score 10.3 avg_score_100 32.0 std score 22.7
# -----saving models------
# episode  349 score 130.7 ep len 200 avg score 10.7 avg_score_100 33.3 std score 23.6
# -----saving models------
# episode  350 score 121.1 ep len 200 avg score 11.0 avg_score_100 34.4 std score 24.3
# -----saving models------
# episode  351 score 126.3 ep len 200 avg score 11.3 avg_score_100 35.6 std score 25.0
# -----saving models------
# episode  352 score 129.3 ep len 200 avg score 11.6 avg_score_100 36.9 std score 25.7
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  353 score 132.1 ep len 200 avg score 12.0 avg_score_100 38.2 std score 26.5
# -----saving models------
# episode  354 score 139.1 ep len 200 avg score 12.3 avg_score_100 39.5 std score 27.3
# -----saving models------
# episode  355 score 130.0 ep len 200 avg score 12.7 avg_score_100 40.7 std score 28.0
# -----saving models------
# episode  356 score 129.6 ep len 200 avg score 13.0 avg_score_100 42.0 std score 28.6
# -----saving models------
# episode  357 score 116.8 ep len 200 avg score 13.3 avg_score_100 43.1 std score 29.1
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  358 score 127.3 ep len 200 avg score 13.6 avg_score_100 44.3 std score 29.6
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# Target Updated
# -----saving models------
# episode  359 score 126.3 ep len 200 avg score 13.9 avg_score_100 45.5 std score 30.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2270177/648861209.py in ?()
#      25                 done = True
#      26
#      27             agent.remember(state=observation, action=action_index, done=done,
#      28                             reward=reward, new_state=new_observation)
# ---> 29             agent.train()
#      30
#      31             observation = new_observation
#      32
#
# ~/Documents/thesis/ddqn_her/ddqn.py in ?(self)
#     133         q_target[batch_index, action_indices] = reward + \
#     134                     self.gamma*q_next[batch_index, max_actions.astype(int)]*done
#     135
#     136         #* now we fit the main model (q_eval)
# --> 137         _ = self.q_eval.fit(state, q_target, verbose = 0) # type: ignore
#     138
#     139         #* If counter reaches set value, update target network with weights of main network
#     140         #* it will update it at the very beginning also
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1802                         "information of where went wrong, or file a "
#    1803                         "issue/bug to `tf.keras`."
#    1804                     )
#    1805                 # Override with model metrics instead of last step logs
# -> 1806                 logs = self._validate_and_get_metrics_result(logs)
#    1807                 epoch_logs = copy.copy(logs)
#    1808
#    1809                 # Run validation.
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py in ?(self, logs)
#    1275         Using the results of last step function could lead to incorrect \
#    1276         results when used with ParameterServerStrategy"
#    1277         try:
#    1278             metric_logs = self.get_metrics_result()
# -> 1279         except TypeError:
#    1280             if self._cluster_coordinator:
#    1281                 logging.warning(PSS_WARN_MSG)
#    1282         else:
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py in ?(self)
#    1238         """
#    1239         # Collect metrics to return
#    1240         return_metrics = {}
#    1241         for metric in self.metrics:
# -> 1242             result = metric.result()
#    1243             if isinstance(result, dict):
#    1244                 return_metrics.update(result)
#    1245             else:
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/metrics_utils.py in ?(metric_obj, *args)
#     138                 raw_result = result_fn(*args)
#     139                 # Results need to be wrapped in a `tf.identity` op to ensure
#     140                 # correct execution order.
#     141                 if isinstance(raw_result, (tf.Tensor, tf.Variable, float, int)):
# --> 142                     result_t = tf.identity(raw_result)
#     143                 elif isinstance(raw_result, dict):
#     144                     result_t = tf.nest.map_structure(tf.identity, raw_result)
#     145                 else:
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py in ?(input, name)
#     317   if context.executing_eagerly() and not hasattr(input, "graph"):
#     318     # Make sure we get an input with handle data attached from resource
#     319     # variables. Variables have correct handle data when graph building.
#     320     input = ops.convert_to_tensor(input)
# --> 321   ret = gen_array_ops.identity(input, name=name)
#     322   # Propagate handle data for happier shape inference for resource variables.
#     323   if hasattr(input, "_handle_data"):
#     324     ret._handle_data = input._handle_data  # pylint: disable=protected-access
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/ops/gen_array_ops.py in ?(input, name)
#    4184         _ctx, "Identity", name, input)
#    4185       return _result
#    4186     except _core._NotOkStatusException as e:
#    4187       _ops.raise_from_not_ok_status(e, name)
# -> 4188     except _core._FallbackException:
#    4189       pass
#    4190     try:
#    4191       return identity_eager_fallback(
#
# KeyboardInterrupt:

# %%
n_steps = sum(episode_lens)
print(n_steps)
# Out:
# 12504

# %%
# env = record_videos(env)
from gymnasium.wrappers import RecordVideo

data = load_config()
env = gym.make('racetrack-v0', render_mode = 'rgb_array')
env.configure(data) # type: ignore

env = RecordVideo(env, video_folder="videos", episode_trigger=lambda e: True)
env.unwrapped.set_record_video_wrapper(env)

# main loop
for episode in trange(1, desc='Test episodes'):

        proc.reset()
        (observation, info), done = env.reset(), False
        truncated = False
        proc.update_input(observation, info)
        observation = proc.get_input()

        episode_reward = 0
        episode_len = 0

        while (not done) or truncated:
            
            action, action_index = agent.get_action(observation, deterministic=True)
            new_observation, reward, done, truncated, new_info = env.step(action=[action])
            
            proc.update_input(new_observation, info)
            new_observation = proc.get_input()

            episode_reward += reward # type: ignore
            episode_len +=1

            if new_info["rewards"]["on_road_reward"] == False or episode_len >=150:
               done = True
            
            observation = new_observation

        print('episode ', episode, 'score %.1f' % episode_reward, 'ep len', episode_len)   

env.close()
# Out:
# /home/o/Documents/thesis/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.configure to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.configure` for environment variables or `env.get_wrapper_attr('configure')` that will search the reminding wrappers.
#   logger.warn(
# Test episodes:   0%|          | 0/1 [00:00<?, ?it/s]
# episode  0 score 116.7 ep len 150
# Moviepy - Building video /home/o/Documents/thesis/ddqn_her/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /home/o/Documents/thesis/ddqn_her/videos/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /home/o/Documents/thesis/ddqn_her/videos/rl-video-episode-0.mp4
