# %%
# fundemental modules
import gymnasium as gym
import highway_env
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import gc
import time
import pprint
from tqdm.notebook import trange
import sys

# %%
# display visuals 
from utils import record_videos, show_videos

# %%
# deep learning modules
from keras.optimizers import Adam
from keras.layers import Dense, Flatten
from keras.models import Sequential
from keras.optimizers import Adam
import tensorflow as tf
import keras.backend as K
from keras.utils import plot_model
tf.random.set_seed(43)
import keras

# %%
class ReplayBuffer:
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cnt = 0
        self.state_memory = np.zeros((self.mem_size,*input_shape), dtype=np.float16)
        self.new_state_memory = np.zeros((self.mem_size, *input_shape),dtype=np.float16)
        self.action_memory = np.zeros((self.mem_size, n_actions),dtype=np.float16)
        self.reward_memory = np.zeros(self.mem_size,dtype=np.float16)
        self.terminal_memory = np.zeros(self.mem_size, dtype = bool)
        
    def store_transition(self, state, action, reward,
                         new_state, done):
        
        index = self.mem_cnt % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = new_state
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done

        self.mem_cnt += 1

    def sample_bufer(self, batch_size):

        max_mem = min(self.mem_cnt, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)

        states = self.state_memory[batch]
        states_= self.new_state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones

# %%
class CriticNetwork(keras.Model):
    def __init__(self, fc1_dims = 512, fc2_dims = 512,
                 name = 'critic', chkpt_dir = 'tmp/ddpg'):
        super(CriticNetwork, self).__init__()

        self.model_name = name
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir,
                                            self.model_name + '_ddpg.h5')
        
        
        # self.conv1 = Conv2D(24, 8, strides=2, activation="relu", padding="same")
        # self.conv2 = Conv2D(32, 8, strides=1, activation="relu", padding="same")
        self.flatten = Flatten()

        self.fc1 = Dense(units=512, activation='relu')
        self.fc2 = Dense(units=512, activation='relu')
        self.q = Dense(1,activation=None)

    def call(self, state, action):

        state_value = self.fc1(tf.concat([state, action], axis = 1))
        # conv_b = self.conv2(conv_a)
        # flat = self.flatten(state_value)

        action_value = self.fc2(state_value)
        q = self.q(action_value)

        return q
    
class ActorNetwork(keras.Model):
    def __init__(self, n_actions=1, fc1_dims = 512, fc2_dims = 512,
                 name = 'actor', chkpt_dir = 'tmp/ddpg'):
        super(ActorNetwork, self).__init__()

        self.n_actions = n_actions
        self.model_name = name
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir,
                                            self.model_name + '_ddpg.h5')
        
        # self.conv1 = Conv2D(24, 8, strides=2, activation="relu", padding="same")
        # self.conv2 = Conv2D(32, 8, strides=1, activation="relu", padding="same")
        # self.flatten = Flatten()
        self.fc1 = Dense(units=512, activation='relu')
        self.fc2 = Dense(units=512, activation='relu')
        self.mu = Dense(self.n_actions ,activation='tanh')

    def call(self, state):

        # conv_a = self.conv1(state)
        # conv_b = self.conv2(conv_a)
        # flat = self.flatten(conv_b)
        prob = self.fc1(state)
        prob = self.fc2(prob)

        mu = self.mu(prob)

        return mu

# %%
class Agent:
    def __init__(self, input_dims, alpha = 0.001,
                 beta = 0.002, gamma = .99,
                 n_actions = 1, max_size = 10000,
                 tau = 0.003, batch_size = 64, noise =0.3):
        
        self.gamma = gamma
        self.tau = tau
        self.memory = ReplayBuffer(max_size, input_dims, n_actions)
        self.batch_size = batch_size
        self.n_actions = n_actions
        self.noise = noise
        self.max_action = 1.0
        self.min_action = -1.0

        self.actor = ActorNetwork(n_actions = n_actions, name = 'actor')
        self.critic = CriticNetwork(name = 'critic')
        self.target_actor = ActorNetwork(n_actions=n_actions,
                                         name = 'target_actor')
        self.target_critic = CriticNetwork(name = 'target_critic')

        self.actor.compile(optimizer=Adam(learning_rate=alpha))
        self.critic.compile(optimizer=Adam(learning_rate=beta))
        self.target_actor.compile(optimizer=Adam(learning_rate=alpha))
        self.target_critic.compile(optimizer=Adam(learning_rate=beta))

        self.update_network_parameters(tau=1)

    def update_network_parameters(self, tau=None):

        if tau is None:
            tau = self.tau

        weights = []
        targets = self.target_actor.weights
        for i, weight in enumerate(self.actor.weights):
            weights.append(weight*tau + targets[i]*(1-tau))
        self.target_actor.set_weights(weights)

        weights = []
        targets = self.target_critic.weights
        for i,weight in enumerate(self.critic.weights):
            weights.append(weight*tau + targets[i]*(1-tau))
        self.target_critic.set_weights(weights)

    def remember(self, state, action, reward, new_state, done):
        self.memory.store_transition(state,action,reward,new_state,done)

    def save_model(self, episode):
        print("-----saving models------")
        self.actor.save_weights(f"weights/ddpg/ddpg_actor-{episode}.h5")
        self.critic.save_weights(f"weights/ddpg/ddpg_critic-{episode}.h5")
        # self.target_actor.save_weights(self.target_actor.checkpoint_file)
        # self.target_critic.save_weights(self.target_critic.checkpoint_file)

    def load_model(self):
        pass

    def choose_action(self,observation, evaluate=False):
        state = tf.convert_to_tensor([observation], dtype=tf.float32)
        actions = self.actor(state)
        if not evaluate:
            actions += tf.random.normal(shape =[self.n_actions],
                                         mean= 0.0, stddev = self.noise) # type: ignore

        actions = tf.clip_by_value(actions, self.min_action, self.max_action)

        return actions[0] # type: ignore
    
    def learn(self):
        if self.memory.mem_cnt < self.batch_size:
            return
        state, action, reward, new_state, done = \
        self.memory.sample_bufer(self.batch_size)

        states = tf.convert_to_tensor(state, dtype=np.float32)
        states_ = tf.convert_to_tensor(new_state, dtype = np.float32)
        actions = tf.convert_to_tensor(action, dtype=np.float32)
        rewards = tf.convert_to_tensor(reward, dtype=np.float32)

        with tf.GradientTape() as tape:
            target_actions = self.target_actor(states_)
            critic_value_ = tf.squeeze(self.target_critic(
                states_, target_actions),1)
            
            critic_value = tf.squeeze(self.critic(states,actions),1)
            target = reward + self.gamma*critic_value_*(1-done)

            critic_loss = keras.losses.MSE(target, critic_value)

        critic_network_gradient = tape.gradient(critic_loss,
                                                self.critic.trainable_variables)
        self.critic.optimizer.apply_gradients(zip(
            critic_network_gradient, self.critic.trainable_variables))
        
        with tf.GradientTape() as tape:
            new_policy_actions = self.actor(states)
            actor_loss = -self.critic(states, new_policy_actions)
            actor_loss = tf.math.reduce_mean(actor_loss)

        actor_network_gradient = tape.gradient(actor_loss,
                                               self.actor.trainable_variables)
        
        self.actor.optimizer.apply_gradients(zip(
            actor_network_gradient, self.actor.trainable_variables))
        
        self.update_network_parameters()

        gc.collect()
        K.clear_session()

# %%
# envirenment config

env = gym.make('racetrack-v0', render_mode='rgb_array')
env.configure({
    'action': {'lateral': True,
            'longitudinal': False,
            'target_speeds': [0, 3],
            'type': 'ContinuousAction'},
    "observation": {
        "type": "Kinematics",
        "vehicles_count": 2,
        "features": ["presence", "x", "y", "vx", "vy", "cos_h", "sin_h",
                     "heading", "long_off", "lat_off", "ang_off"],
    },
    'show_trajectories': True,
    "other_vehicles": 1

})
# Out:
# /home/o/.pyenv/versions/3.10.13/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.configure to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.configure` for environment variables or `env.get_wrapper_attr('configure')` that will search the reminding wrappers.
#   logger.warn(

# %%
# prints env configs
#* obs is flattened to 1D array for nn

pprint.pprint(env.config)
(obs, info), done = env.reset(), False
obs = np.array(obs.flatten())
print("Environment is setted up.")
# Out:
# {'action': {'lateral': True,
#             'longitudinal': False,
#             'target_speeds': [0, 3],
#             'type': 'ContinuousAction'},
#  'action_reward': -0.3,
#  'centering_position': [0.5, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 300,
#  'lane_centering_cost': 4,
#  'lane_centering_reward': 1,
#  'manual_control': False,
#  'observation': {'features': ['presence',
#                               'x',
#                               'y',
#                               'vx',
#                               'vy',
#                               'cos_h',
#                               'sin_h',
#                               'heading',
#                               'long_off',
#                               'lat_off',
#                               'ang_off'],
#                  'type': 'Kinematics',
#                  'vehicles_count': 2},
#  'offscreen_rendering': False,
#  'other_vehicles': 1,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 5,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'scaling': 5.5,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': True,
#  'simulation_frequency': 15}
# Environment is setted up.
# /home/o/.pyenv/versions/3.10.13/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %%
agent = Agent(input_dims=obs.shape,
                  n_actions=1)

# %%
#* basic params for training

best_score = -1000.0
score_history = []

# %%
for episode in trange(2000, desc='Test episodes'):
        score = 0
        (observation, info), done = env.reset(), False
        observation = np.array(observation.flatten())

        done_ = False
        score = 0
        step = 0
        truncated = False

        while not done_:
            action = agent.choose_action(observation, evaluate = False)
            act = np.array(action)
            new_observation, reward, done, truncated, info = env.step(act) # type: ignore

            new_observation = np.array(new_observation.flatten())

            if info["crashed"] == True or info["rewards"]["on_road_reward"] == False or truncated == True:
                done_ = True
                reward = -10.0
            else: done_ = False

            score += reward

            agent.remember(observation,action,reward,new_observation,done)

            agent.learn()
            observation = new_observation
            step +=1

        score_history.append(score)
        avg_score = np.mean(score_history[-100:])

        if avg_score > best_score:
            best_score = avg_score
            agent.save_model(episode)

        print('episode ', episode, 'score %.1f' % score,
               'avg score %.1f' % avg_score, 'best_score %.1f' % best_score)
        # time.sleep(1)

env.close()
# Out:
# Test episodes:   0%|          | 0/2000 [00:00<?, ?it/s]
# -----saving models------
# episode  0 score -3.3 avg score -3.3 best_score -3.3
# episode  1 score -8.1 avg score -5.7 best_score -3.3
# episode  2 score -4.6 avg score -5.3 best_score -3.3
# episode  3 score -7.6 avg score -5.9 best_score -3.3
# episode  4 score -6.4 avg score -6.0 best_score -3.3
# episode  5 score -6.5 avg score -6.1 best_score -3.3
# episode  6 score -8.8 avg score -6.5 best_score -3.3
# episode  7 score -5.0 avg score -6.3 best_score -3.3
# episode  8 score -8.5 avg score -6.5 best_score -3.3
# episode  9 score -8.3 avg score -6.7 best_score -3.3
# episode  10 score -6.4 avg score -6.7 best_score -3.3
# episode  11 score -8.2 avg score -6.8 best_score -3.3
# episode  12 score -9.1 avg score -7.0 best_score -3.3
# episode  13 score -8.2 avg score -7.1 best_score -3.3
# episode  14 score -9.1 avg score -7.2 best_score -3.3
# episode  15 score -8.2 avg score -7.3 best_score -3.3
# episode  16 score -8.1 avg score -7.3 best_score -3.3
# episode  17 score -9.1 avg score -7.4 best_score -3.3
# episode  18 score -9.1 avg score -7.5 best_score -3.3
# episode  19 score -9.6 avg score -7.6 best_score -3.3
# episode  20 score -8.2 avg score -7.6 best_score -3.3
# episode  21 score -9.0 avg score -7.7 best_score -3.3
# episode  22 score -9.0 avg score -7.8 best_score -3.3
# episode  23 score -9.0 avg score -7.8 best_score -3.3
# episode  24 score -8.1 avg score -7.8 best_score -3.3
# episode  25 score -8.2 avg score -7.8 best_score -3.3
# episode  26 score -9.1 avg score -7.9 best_score -3.3
# episode  27 score -9.6 avg score -7.9 best_score -3.3
# episode  28 score -9.6 avg score -8.0 best_score -3.3
# episode  29 score -9.2 avg score -8.0 best_score -3.3
# episode  30 score -9.6 avg score -8.1 best_score -3.3
# episode  31 score -8.2 avg score -8.1 best_score -3.3
# episode  32 score -8.1 avg score -8.1 best_score -3.3
# episode  33 score -9.6 avg score -8.1 best_score -3.3
# episode  34 score -9.6 avg score -8.2 best_score -3.3
# episode  35 score -8.2 avg score -8.2 best_score -3.3
# episode  36 score -9.1 avg score -8.2 best_score -3.3
# episode  37 score -9.6 avg score -8.2 best_score -3.3
# episode  38 score -8.2 avg score -8.2 best_score -3.3
# episode  39 score -9.1 avg score -8.3 best_score -3.3
# episode  40 score -9.6 avg score -8.3 best_score -3.3
# episode  41 score -9.6 avg score -8.3 best_score -3.3
# episode  42 score -9.1 avg score -8.3 best_score -3.3
# episode  43 score -9.6 avg score -8.4 best_score -3.3
# episode  44 score -8.1 avg score -8.4 best_score -3.3
# episode  45 score -8.2 avg score -8.4 best_score -3.3
# episode  46 score -8.2 avg score -8.3 best_score -3.3
# episode  47 score -8.2 avg score -8.3 best_score -3.3
# episode  48 score -9.6 avg score -8.4 best_score -3.3
# episode  49 score -8.2 avg score -8.4 best_score -3.3
# episode  50 score -8.1 avg score -8.4 best_score -3.3
# episode  51 score -8.9 avg score -8.4 best_score -3.3
# episode  52 score -8.2 avg score -8.4 best_score -3.3
# episode  53 score -9.1 avg score -8.4 best_score -3.3
# episode  54 score -8.1 avg score -8.4 best_score -3.3
# episode  55 score -9.6 avg score -8.4 best_score -3.3
# episode  56 score -8.1 avg score -8.4 best_score -3.3
# episode  57 score -9.1 avg score -8.4 best_score -3.3
# episode  58 score -8.1 avg score -8.4 best_score -3.3
# episode  59 score -8.2 avg score -8.4 best_score -3.3
# episode  60 score -7.5 avg score -8.4 best_score -3.3
# episode  61 score -8.2 avg score -8.4 best_score -3.3
# episode  62 score -8.1 avg score -8.4 best_score -3.3
# episode  63 score -8.1 avg score -8.4 best_score -3.3
# episode  64 score -8.2 avg score -8.4 best_score -3.3
# episode  65 score -9.0 avg score -8.4 best_score -3.3
# episode  66 score -9.6 avg score -8.4 best_score -3.3
# episode  67 score -8.2 avg score -8.4 best_score -3.3
# episode  68 score -9.1 avg score -8.4 best_score -3.3
# episode  69 score -9.6 avg score -8.4 best_score -3.3
# episode  70 score -8.7 avg score -8.4 best_score -3.3
# episode  71 score -7.3 avg score -8.4 best_score -3.3
# episode  72 score -8.2 avg score -8.4 best_score -3.3
# episode  73 score -8.1 avg score -8.4 best_score -3.3
# episode  74 score -8.1 avg score -8.4 best_score -3.3
# episode  75 score -8.1 avg score -8.4 best_score -3.3
# episode  76 score -8.1 avg score -8.4 best_score -3.3
# episode  77 score -7.5 avg score -8.4 best_score -3.3
# episode  78 score -9.1 avg score -8.4 best_score -3.3
# episode  79 score -8.1 avg score -8.4 best_score -3.3
# episode  80 score -9.1 avg score -8.4 best_score -3.3
# episode  81 score -8.2 avg score -8.4 best_score -3.3
# episode  82 score -8.1 avg score -8.4 best_score -3.3
# episode  83 score -8.2 avg score -8.4 best_score -3.3
# episode  84 score -8.2 avg score -8.4 best_score -3.3
# episode  85 score -8.2 avg score -8.4 best_score -3.3
# episode  86 score -8.1 avg score -8.4 best_score -3.3
# episode  87 score -8.1 avg score -8.4 best_score -3.3
# episode  88 score -9.1 avg score -8.4 best_score -3.3
# episode  89 score -8.1 avg score -8.4 best_score -3.3
# episode  90 score -9.0 avg score -8.4 best_score -3.3
# episode  91 score -8.2 avg score -8.4 best_score -3.3
# episode  92 score -8.1 avg score -8.4 best_score -3.3
# episode  93 score -9.6 avg score -8.4 best_score -3.3
# episode  94 score -8.2 avg score -8.4 best_score -3.3
# episode  95 score -9.1 avg score -8.4 best_score -3.3
# episode  96 score -9.5 avg score -8.4 best_score -3.3
# episode  97 score -8.0 avg score -8.4 best_score -3.3
# episode  98 score -9.6 avg score -8.4 best_score -3.3
# episode  99 score -9.1 avg score -8.4 best_score -3.3
# episode  100 score -8.1 avg score -8.5 best_score -3.3
# episode  101 score -7.4 avg score -8.5 best_score -3.3
# episode  102 score -8.1 avg score -8.5 best_score -3.3
# episode  103 score -8.2 avg score -8.5 best_score -3.3
# episode  104 score -9.6 avg score -8.5 best_score -3.3
# episode  105 score -8.2 avg score -8.6 best_score -3.3
# episode  106 score -7.5 avg score -8.5 best_score -3.3
# episode  107 score -8.1 avg score -8.6 best_score -3.3
# episode  108 score -8.1 avg score -8.6 best_score -3.3
# episode  109 score -8.2 avg score -8.6 best_score -3.3
# episode  110 score -9.1 avg score -8.6 best_score -3.3
# episode  111 score -9.1 avg score -8.6 best_score -3.3
# episode  112 score -9.1 avg score -8.6 best_score -3.3
# episode  113 score -9.6 avg score -8.6 best_score -3.3
# episode  114 score -9.6 avg score -8.6 best_score -3.3
# episode  115 score -8.1 avg score -8.6 best_score -3.3
# episode  116 score -8.2 avg score -8.6 best_score -3.3
# episode  117 score -9.1 avg score -8.6 best_score -3.3
# episode  118 score -8.2 avg score -8.6 best_score -3.3
# episode  119 score -7.3 avg score -8.6 best_score -3.3
# episode  120 score -8.2 avg score -8.6 best_score -3.3
# episode  121 score -9.2 avg score -8.6 best_score -3.3
# episode  122 score -9.6 avg score -8.6 best_score -3.3
# episode  123 score -8.1 avg score -8.6 best_score -3.3
# episode  124 score -9.6 avg score -8.6 best_score -3.3
# episode  125 score -9.6 avg score -8.6 best_score -3.3
# episode  126 score -9.6 avg score -8.6 best_score -3.3
# episode  127 score -9.6 avg score -8.6 best_score -3.3
# episode  128 score -9.1 avg score -8.6 best_score -3.3
# episode  129 score -8.1 avg score -8.6 best_score -3.3
# episode  130 score -8.2 avg score -8.6 best_score -3.3
# episode  131 score -9.5 avg score -8.6 best_score -3.3
# episode  132 score -8.2 avg score -8.6 best_score -3.3
# episode  133 score -7.2 avg score -8.6 best_score -3.3
# episode  134 score -9.6 avg score -8.6 best_score -3.3
# episode  135 score -9.1 avg score -8.6 best_score -3.3
# episode  136 score -9.1 avg score -8.6 best_score -3.3
# episode  137 score -8.2 avg score -8.6 best_score -3.3
# episode  138 score -8.1 avg score -8.6 best_score -3.3
# episode  139 score -8.1 avg score -8.6 best_score -3.3
# episode  140 score -8.2 avg score -8.6 best_score -3.3
# episode  141 score -8.1 avg score -8.5 best_score -3.3
# episode  142 score -9.2 avg score -8.5 best_score -3.3
# episode  143 score -8.1 avg score -8.5 best_score -3.3
# episode  144 score -8.1 avg score -8.5 best_score -3.3
# episode  145 score -8.9 avg score -8.5 best_score -3.3
# episode  146 score -9.6 avg score -8.5 best_score -3.3
# episode  147 score -9.6 avg score -8.6 best_score -3.3
# episode  148 score -9.0 avg score -8.6 best_score -3.3
# episode  149 score -8.1 avg score -8.6 best_score -3.3
# episode  150 score -8.1 avg score -8.6 best_score -3.3
# episode  151 score -9.5 avg score -8.6 best_score -3.3
# episode  152 score -9.1 avg score -8.6 best_score -3.3
# episode  153 score -8.1 avg score -8.6 best_score -3.3
# episode  154 score -9.1 avg score -8.6 best_score -3.3
# episode  155 score -7.5 avg score -8.6 best_score -3.3
# episode  156 score -9.1 avg score -8.6 best_score -3.3
# episode  157 score -9.6 avg score -8.6 best_score -3.3
# episode  158 score -9.6 avg score -8.6 best_score -3.3
# episode  159 score -9.1 avg score -8.6 best_score -3.3
# episode  160 score -9.6 avg score -8.6 best_score -3.3
# episode  161 score -9.6 avg score -8.6 best_score -3.3
# episode  162 score -9.6 avg score -8.6 best_score -3.3
# episode  163 score -8.2 avg score -8.6 best_score -3.3
# episode  164 score -9.0 avg score -8.6 best_score -3.3
# episode  165 score -9.2 avg score -8.6 best_score -3.3
# episode  166 score -8.1 avg score -8.6 best_score -3.3
# episode  167 score -8.2 avg score -8.6 best_score -3.3
# episode  168 score -9.6 avg score -8.6 best_score -3.3
# episode  169 score -9.6 avg score -8.6 best_score -3.3
# episode  170 score -7.3 avg score -8.6 best_score -3.3
# episode  171 score -9.1 avg score -8.6 best_score -3.3
# episode  172 score -9.6 avg score -8.7 best_score -3.3
# episode  173 score -8.2 avg score -8.7 best_score -3.3
# episode  174 score -9.6 avg score -8.7 best_score -3.3
# episode  175 score -8.1 avg score -8.7 best_score -3.3
# episode  176 score -9.6 avg score -8.7 best_score -3.3
# episode  177 score -7.2 avg score -8.7 best_score -3.3
# episode  178 score -7.4 avg score -8.7 best_score -3.3
# episode  179 score -8.2 avg score -8.7 best_score -3.3
# episode  180 score -6.3 avg score -8.6 best_score -3.3
# episode  181 score -8.2 avg score -8.6 best_score -3.3
# episode  182 score -8.0 avg score -8.6 best_score -3.3
# episode  183 score -9.1 avg score -8.6 best_score -3.3
# episode  184 score -8.1 avg score -8.6 best_score -3.3
# episode  185 score -7.4 avg score -8.6 best_score -3.3
# episode  186 score -8.1 avg score -8.6 best_score -3.3
# episode  187 score -8.1 avg score -8.6 best_score -3.3
# episode  188 score -9.6 avg score -8.6 best_score -3.3
# episode  189 score -9.5 avg score -8.7 best_score -3.3
# episode  190 score -7.2 avg score -8.6 best_score -3.3
# episode  191 score -9.1 avg score -8.6 best_score -3.3
# episode  192 score -8.2 avg score -8.6 best_score -3.3
# episode  193 score -9.6 avg score -8.6 best_score -3.3
# episode  194 score -9.1 avg score -8.7 best_score -3.3
# episode  195 score -9.6 avg score -8.7 best_score -3.3
# episode  196 score -8.1 avg score -8.6 best_score -3.3
# episode  197 score -9.1 avg score -8.7 best_score -3.3
# episode  198 score -9.6 avg score -8.7 best_score -3.3
# episode  199 score -8.1 avg score -8.6 best_score -3.3
# episode  200 score -9.6 avg score -8.7 best_score -3.3
# episode  201 score -8.1 avg score -8.7 best_score -3.3
# episode  202 score -9.6 avg score -8.7 best_score -3.3
# episode  203 score -9.6 avg score -8.7 best_score -3.3
# episode  204 score -9.6 avg score -8.7 best_score -3.3
# episode  205 score -7.4 avg score -8.7 best_score -3.3
# episode  206 score -9.6 avg score -8.7 best_score -3.3
# episode  207 score -9.6 avg score -8.7 best_score -3.3
# episode  208 score -9.5 avg score -8.7 best_score -3.3
# episode  209 score -7.2 avg score -8.7 best_score -3.3
# episode  210 score -8.2 avg score -8.7 best_score -3.3
# episode  211 score -9.6 avg score -8.7 best_score -3.3
# episode  212 score -8.1 avg score -8.7 best_score -3.3
# episode  213 score -8.1 avg score -8.7 best_score -3.3
# episode  214 score -8.1 avg score -8.7 best_score -3.3
# episode  215 score -9.6 avg score -8.7 best_score -3.3
# episode  216 score -8.2 avg score -8.7 best_score -3.3
# episode  217 score -9.1 avg score -8.7 best_score -3.3
# episode  218 score -9.1 avg score -8.7 best_score -3.3
# episode  219 score -9.2 avg score -8.7 best_score -3.3
# episode  220 score -9.6 avg score -8.7 best_score -3.3
# episode  221 score -8.1 avg score -8.7 best_score -3.3
# episode  222 score -9.1 avg score -8.7 best_score -3.3
# episode  223 score -8.1 avg score -8.7 best_score -3.3
# episode  224 score -9.6 avg score -8.7 best_score -3.3
# episode  225 score -8.2 avg score -8.7 best_score -3.3
# episode  226 score -9.6 avg score -8.7 best_score -3.3
# episode  227 score -9.6 avg score -8.7 best_score -3.3
# episode  228 score -8.1 avg score -8.7 best_score -3.3
# episode  229 score -9.6 avg score -8.7 best_score -3.3
# episode  230 score -8.2 avg score -8.7 best_score -3.3
# episode  231 score -9.6 avg score -8.7 best_score -3.3
# episode  232 score -9.1 avg score -8.7 best_score -3.3
# episode  233 score -8.2 avg score -8.7 best_score -3.3
# episode  234 score -8.1 avg score -8.7 best_score -3.3
# episode  235 score -8.1 avg score -8.7 best_score -3.3
# episode  236 score -9.5 avg score -8.7 best_score -3.3
# episode  237 score -8.2 avg score -8.7 best_score -3.3
# episode  238 score -8.1 avg score -8.7 best_score -3.3
# episode  239 score -9.2 avg score -8.7 best_score -3.3
# episode  240 score -7.4 avg score -8.7 best_score -3.3
# episode  241 score -9.6 avg score -8.7 best_score -3.3
# episode  242 score -8.2 avg score -8.7 best_score -3.3
# episode  243 score -8.2 avg score -8.7 best_score -3.3
# episode  244 score -9.6 avg score -8.7 best_score -3.3
# episode  245 score -8.2 avg score -8.7 best_score -3.3
# episode  246 score -9.1 avg score -8.7 best_score -3.3
# episode  247 score -8.2 avg score -8.7 best_score -3.3
# episode  248 score -8.1 avg score -8.7 best_score -3.3
# episode  249 score -9.0 avg score -8.7 best_score -3.3
# episode  250 score -9.1 avg score -8.7 best_score -3.3
# episode  251 score -8.1 avg score -8.7 best_score -3.3
# episode  252 score -9.5 avg score -8.7 best_score -3.3
# episode  253 score -8.1 avg score -8.7 best_score -3.3
# episode  254 score -8.2 avg score -8.7 best_score -3.3
# episode  255 score -8.9 avg score -8.7 best_score -3.3
# episode  256 score -8.2 avg score -8.7 best_score -3.3
# episode  257 score -9.5 avg score -8.7 best_score -3.3
# episode  258 score -8.0 avg score -8.7 best_score -3.3
# episode  259 score -9.1 avg score -8.7 best_score -3.3
# episode  260 score -8.1 avg score -8.7 best_score -3.3
# episode  261 score -9.1 avg score -8.7 best_score -3.3
# episode  262 score -9.6 avg score -8.7 best_score -3.3
# episode  263 score -8.2 avg score -8.7 best_score -3.3
# episode  264 score -9.1 avg score -8.7 best_score -3.3
# episode  265 score -9.6 avg score -8.7 best_score -3.3
# episode  266 score -9.6 avg score -8.7 best_score -3.3
# episode  267 score -9.1 avg score -8.7 best_score -3.3
# episode  268 score -9.6 avg score -8.7 best_score -3.3
# episode  269 score -8.2 avg score -8.7 best_score -3.3
# episode  270 score -9.1 avg score -8.7 best_score -3.3
# episode  271 score -9.0 avg score -8.7 best_score -3.3
# episode  272 score -6.5 avg score -8.7 best_score -3.3
# episode  273 score -9.1 avg score -8.7 best_score -3.3
# episode  274 score -8.2 avg score -8.7 best_score -3.3
# episode  275 score -8.1 avg score -8.7 best_score -3.3
# episode  276 score -8.1 avg score -8.7 best_score -3.3
# episode  277 score -7.4 avg score -8.7 best_score -3.3
# episode  278 score -9.6 avg score -8.7 best_score -3.3
# episode  279 score -8.1 avg score -8.7 best_score -3.3
# episode  280 score -8.1 avg score -8.7 best_score -3.3
# episode  281 score -9.1 avg score -8.7 best_score -3.3
# episode  282 score -9.1 avg score -8.7 best_score -3.3
# episode  283 score -8.1 avg score -8.7 best_score -3.3
# episode  284 score -9.1 avg score -8.7 best_score -3.3
# episode  285 score -9.6 avg score -8.7 best_score -3.3
# episode  286 score -9.6 avg score -8.8 best_score -3.3
# episode  287 score -8.2 avg score -8.8 best_score -3.3
# episode  288 score -9.2 avg score -8.8 best_score -3.3
# episode  289 score -9.0 avg score -8.7 best_score -3.3
# episode  290 score -9.1 avg score -8.8 best_score -3.3
# episode  291 score -9.1 avg score -8.8 best_score -3.3
# episode  292 score -9.1 avg score -8.8 best_score -3.3
# episode  293 score -8.2 avg score -8.8 best_score -3.3
# episode  294 score -9.6 avg score -8.8 best_score -3.3
# episode  295 score -8.8 avg score -8.8 best_score -3.3
# episode  296 score -8.1 avg score -8.8 best_score -3.3
# episode  297 score -9.5 avg score -8.8 best_score -3.3
# episode  298 score -9.6 avg score -8.8 best_score -3.3
# episode  299 score -9.6 avg score -8.8 best_score -3.3
# episode  300 score -9.6 avg score -8.8 best_score -3.3
# episode  301 score -9.6 avg score -8.8 best_score -3.3
# episode  302 score -8.0 avg score -8.8 best_score -3.3
# episode  303 score -9.1 avg score -8.8 best_score -3.3
# episode  304 score -9.1 avg score -8.8 best_score -3.3
# episode  305 score -7.6 avg score -8.8 best_score -3.3
# episode  306 score -9.2 avg score -8.8 best_score -3.3
# episode  307 score -9.0 avg score -8.8 best_score -3.3
# episode  308 score -9.5 avg score -8.8 best_score -3.3
# episode  309 score -8.2 avg score -8.8 best_score -3.3
# episode  310 score -8.1 avg score -8.8 best_score -3.3
# episode  311 score -9.1 avg score -8.8 best_score -3.3
# episode  312 score -8.2 avg score -8.8 best_score -3.3
# episode  313 score -8.2 avg score -8.8 best_score -3.3
# episode  314 score -8.2 avg score -8.8 best_score -3.3
# episode  315 score -8.1 avg score -8.8 best_score -3.3
# episode  316 score -8.2 avg score -8.8 best_score -3.3
# episode  317 score -9.6 avg score -8.8 best_score -3.3
# episode  318 score -9.6 avg score -8.8 best_score -3.3
# episode  319 score -9.6 avg score -8.8 best_score -3.3
# episode  320 score -8.2 avg score -8.8 best_score -3.3
# episode  321 score -9.6 avg score -8.8 best_score -3.3
# episode  322 score -9.1 avg score -8.8 best_score -3.3
# episode  323 score -8.2 avg score -8.8 best_score -3.3
# episode  324 score -8.1 avg score -8.8 best_score -3.3
# episode  325 score -9.6 avg score -8.8 best_score -3.3
# episode  326 score -9.1 avg score -8.8 best_score -3.3
# episode  327 score -9.6 avg score -8.8 best_score -3.3
# episode  328 score -9.1 avg score -8.8 best_score -3.3
# episode  329 score -8.1 avg score -8.8 best_score -3.3
# episode  330 score -9.1 avg score -8.8 best_score -3.3
# episode  331 score -9.1 avg score -8.8 best_score -3.3
# episode  332 score -9.0 avg score -8.8 best_score -3.3
# episode  333 score -9.1 avg score -8.8 best_score -3.3
# episode  334 score -8.1 avg score -8.8 best_score -3.3
# episode  335 score -9.6 avg score -8.8 best_score -3.3
# episode  336 score -8.1 avg score -8.8 best_score -3.3
# episode  337 score -9.2 avg score -8.8 best_score -3.3
# episode  338 score -9.6 avg score -8.8 best_score -3.3
# episode  339 score -8.2 avg score -8.8 best_score -3.3
# episode  340 score -8.1 avg score -8.8 best_score -3.3
# episode  341 score -9.6 avg score -8.8 best_score -3.3
# episode  342 score -8.2 avg score -8.8 best_score -3.3
# episode  343 score -9.6 avg score -8.8 best_score -3.3
# episode  344 score -9.1 avg score -8.8 best_score -3.3
# episode  345 score -8.1 avg score -8.8 best_score -3.3
# episode  346 score -8.1 avg score -8.8 best_score -3.3
# episode  347 score -7.4 avg score -8.8 best_score -3.3
# episode  348 score -9.6 avg score -8.8 best_score -3.3
# episode  349 score -9.1 avg score -8.8 best_score -3.3
# episode  350 score -8.3 avg score -8.8 best_score -3.3
# episode  351 score -7.6 avg score -8.8 best_score -3.3
# episode  352 score -8.2 avg score -8.8 best_score -3.3
# episode  353 score -9.6 avg score -8.8 best_score -3.3
# episode  354 score -8.1 avg score -8.8 best_score -3.3
# episode  355 score -9.2 avg score -8.8 best_score -3.3
# episode  356 score -9.6 avg score -8.8 best_score -3.3
# episode  357 score -8.2 avg score -8.8 best_score -3.3
# episode  358 score -9.1 avg score -8.8 best_score -3.3
# episode  359 score -8.1 avg score -8.8 best_score -3.3
# episode  360 score -9.6 avg score -8.8 best_score -3.3
# episode  361 score -9.6 avg score -8.8 best_score -3.3
# episode  362 score -9.5 avg score -8.8 best_score -3.3
# episode  363 score -8.2 avg score -8.8 best_score -3.3
# episode  364 score -9.6 avg score -8.8 best_score -3.3
# episode  365 score -9.6 avg score -8.8 best_score -3.3
# episode  366 score -9.6 avg score -8.8 best_score -3.3
# episode  367 score -9.6 avg score -8.8 best_score -3.3
# episode  368 score -8.1 avg score -8.8 best_score -3.3
# episode  369 score -8.2 avg score -8.8 best_score -3.3
# episode  370 score -9.6 avg score -8.8 best_score -3.3
# episode  371 score -8.1 avg score -8.8 best_score -3.3
# episode  372 score -8.2 avg score -8.8 best_score -3.3
# episode  373 score -9.0 avg score -8.8 best_score -3.3
# episode  374 score -9.6 avg score -8.8 best_score -3.3
# episode  375 score -9.1 avg score -8.8 best_score -3.3
# episode  376 score -9.6 avg score -8.9 best_score -3.3
# episode  377 score -8.1 avg score -8.9 best_score -3.3
# episode  378 score -9.0 avg score -8.9 best_score -3.3
# episode  379 score -8.1 avg score -8.9 best_score -3.3
# episode  380 score -9.1 avg score -8.9 best_score -3.3
# episode  381 score -8.1 avg score -8.9 best_score -3.3
# episode  382 score -9.6 avg score -8.9 best_score -3.3
# episode  383 score -8.2 avg score -8.9 best_score -3.3
# episode  384 score -8.2 avg score -8.9 best_score -3.3
# episode  385 score -8.1 avg score -8.8 best_score -3.3
# episode  386 score -9.1 avg score -8.8 best_score -3.3
# episode  387 score -8.2 avg score -8.8 best_score -3.3
# episode  388 score -8.1 avg score -8.8 best_score -3.3
# episode  389 score -8.1 avg score -8.8 best_score -3.3
# episode  390 score -9.6 avg score -8.8 best_score -3.3
# episode  391 score -8.2 avg score -8.8 best_score -3.3
# episode  392 score -9.1 avg score -8.8 best_score -3.3
# episode  393 score -7.5 avg score -8.8 best_score -3.3
# episode  394 score -9.6 avg score -8.8 best_score -3.3
# episode  395 score -8.2 avg score -8.8 best_score -3.3
# episode  396 score -8.1 avg score -8.8 best_score -3.3
# episode  397 score -9.6 avg score -8.8 best_score -3.3
# episode  398 score -8.1 avg score -8.8 best_score -3.3
# episode  399 score -9.5 avg score -8.8 best_score -3.3
# episode  400 score -9.6 avg score -8.8 best_score -3.3
# episode  401 score -8.1 avg score -8.8 best_score -3.3
# episode  402 score -7.5 avg score -8.8 best_score -3.3
# episode  403 score -9.0 avg score -8.8 best_score -3.3
# episode  404 score -9.6 avg score -8.8 best_score -3.3
# episode  405 score -9.1 avg score -8.8 best_score -3.3
# episode  406 score -9.1 avg score -8.8 best_score -3.3
# episode  407 score -9.6 avg score -8.8 best_score -3.3
# episode  408 score -8.2 avg score -8.8 best_score -3.3
# episode  409 score -8.2 avg score -8.8 best_score -3.3
# episode  410 score -9.6 avg score -8.8 best_score -3.3
# episode  411 score -9.1 avg score -8.8 best_score -3.3
# episode  412 score -8.2 avg score -8.8 best_score -3.3
# episode  413 score -9.0 avg score -8.8 best_score -3.3
# episode  414 score -9.6 avg score -8.8 best_score -3.3
# episode  415 score -9.6 avg score -8.8 best_score -3.3
# episode  416 score -8.9 avg score -8.8 best_score -3.3
# episode  417 score -9.1 avg score -8.8 best_score -3.3
# episode  418 score -7.5 avg score -8.8 best_score -3.3
# episode  419 score -7.1 avg score -8.8 best_score -3.3
# episode  420 score -7.6 avg score -8.8 best_score -3.3
# episode  421 score -9.0 avg score -8.8 best_score -3.3
# episode  422 score -8.2 avg score -8.8 best_score -3.3
# episode  423 score -9.6 avg score -8.8 best_score -3.3
# episode  424 score -9.6 avg score -8.8 best_score -3.3
# episode  425 score -8.2 avg score -8.8 best_score -3.3
# episode  426 score -8.2 avg score -8.8 best_score -3.3
# episode  427 score -7.5 avg score -8.7 best_score -3.3
# episode  428 score -8.2 avg score -8.7 best_score -3.3
# episode  429 score -8.1 avg score -8.7 best_score -3.3
# episode  430 score -7.5 avg score -8.7 best_score -3.3
# episode  431 score -9.6 avg score -8.7 best_score -3.3
# episode  432 score -8.1 avg score -8.7 best_score -3.3
# episode  433 score -9.1 avg score -8.7 best_score -3.3
# episode  434 score -8.2 avg score -8.7 best_score -3.3
# episode  435 score -8.2 avg score -8.7 best_score -3.3
# episode  436 score -8.0 avg score -8.7 best_score -3.3
# episode  437 score -8.1 avg score -8.7 best_score -3.3
# episode  438 score -9.6 avg score -8.7 best_score -3.3
# episode  439 score -9.1 avg score -8.7 best_score -3.3
# episode  440 score -9.6 avg score -8.7 best_score -3.3
# episode  441 score -8.2 avg score -8.7 best_score -3.3
# episode  442 score -8.1 avg score -8.7 best_score -3.3
# episode  443 score -9.6 avg score -8.7 best_score -3.3
# episode  444 score -8.2 avg score -8.7 best_score -3.3
# episode  445 score -9.6 avg score -8.7 best_score -3.3
# episode  446 score -9.0 avg score -8.7 best_score -3.3
# episode  447 score -9.6 avg score -8.7 best_score -3.3
# episode  448 score -9.6 avg score -8.7 best_score -3.3
# episode  449 score -7.6 avg score -8.7 best_score -3.3
# episode  450 score -9.1 avg score -8.7 best_score -3.3
# episode  451 score -9.1 avg score -8.7 best_score -3.3
# episode  452 score -9.6 avg score -8.8 best_score -3.3
# episode  453 score -9.5 avg score -8.8 best_score -3.3
# episode  454 score -9.6 avg score -8.8 best_score -3.3
# episode  455 score -9.6 avg score -8.8 best_score -3.3
# episode  456 score -8.9 avg score -8.8 best_score -3.3
# episode  457 score -9.2 avg score -8.8 best_score -3.3
# episode  458 score -9.1 avg score -8.8 best_score -3.3
# episode  459 score -8.1 avg score -8.8 best_score -3.3
# episode  460 score -9.6 avg score -8.8 best_score -3.3
# episode  461 score -7.5 avg score -8.8 best_score -3.3
# episode  462 score -9.6 avg score -8.8 best_score -3.3
# episode  463 score -8.2 avg score -8.8 best_score -3.3
# episode  464 score -8.1 avg score -8.7 best_score -3.3
# episode  465 score -8.2 avg score -8.7 best_score -3.3
# episode  466 score -9.0 avg score -8.7 best_score -3.3
# episode  467 score -9.6 avg score -8.7 best_score -3.3
# episode  468 score -9.2 avg score -8.7 best_score -3.3
# episode  469 score -8.0 avg score -8.7 best_score -3.3
# episode  470 score -9.6 avg score -8.7 best_score -3.3
# episode  471 score -8.2 avg score -8.7 best_score -3.3
# episode  472 score -9.0 avg score -8.7 best_score -3.3
# episode  473 score -8.2 avg score -8.7 best_score -3.3
# episode  474 score -8.2 avg score -8.7 best_score -3.3
# episode  475 score -9.6 avg score -8.7 best_score -3.3
# episode  476 score -8.2 avg score -8.7 best_score -3.3
# episode  477 score -9.1 avg score -8.7 best_score -3.3
# episode  478 score -8.1 avg score -8.7 best_score -3.3
# episode  479 score -8.2 avg score -8.7 best_score -3.3
# episode  480 score -9.6 avg score -8.7 best_score -3.3
# episode  481 score -8.2 avg score -8.7 best_score -3.3
# episode  482 score -8.0 avg score -8.7 best_score -3.3
# episode  483 score -8.2 avg score -8.7 best_score -3.3
# episode  484 score -9.6 avg score -8.7 best_score -3.3
# episode  485 score -8.1 avg score -8.7 best_score -3.3
# episode  486 score -9.1 avg score -8.7 best_score -3.3
# episode  487 score -9.6 avg score -8.7 best_score -3.3
# episode  488 score -9.1 avg score -8.7 best_score -3.3
# episode  489 score -8.2 avg score -8.7 best_score -3.3
# episode  490 score -9.1 avg score -8.7 best_score -3.3
# episode  491 score -9.1 avg score -8.7 best_score -3.3
# episode  492 score -9.6 avg score -8.7 best_score -3.3
# episode  493 score -8.1 avg score -8.8 best_score -3.3
# episode  494 score -8.2 avg score -8.7 best_score -3.3
# episode  495 score -9.2 avg score -8.7 best_score -3.3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/o/Documents/thesis/highway/ddpg.ipynb Cell 11 line 2
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a> score += reward
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=24'>25</a> agent.remember(observation,action,reward,new_observation,done)
# ---> <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=26'>27</a> agent.learn()
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=27'>28</a> observation = new_observation
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=28'>29</a> step +=1
#
# /home/o/Documents/thesis/highway/ddpg.ipynb Cell 11 line 8
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=81'>82</a> target_actions = self.target_actor(states_)
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=82'>83</a> critic_value_ = tf.squeeze(self.target_critic(
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=83'>84</a>     states_, target_actions),1)
# ---> <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=85'>86</a> critic_value = tf.squeeze(self.critic(states,actions),1)
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=86'>87</a> target = reward + self.gamma*critic_value_*(1-done)
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=88'>89</a> critic_loss = keras.losses.MSE(target, critic_value)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py:589, in Model.__call__(self, *args, **kwargs)
#     585         super().__call__(inputs, *copied_args, **copied_kwargs)
#     587     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 589 return super().__call__(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/base_layer.py:1149, in Layer.__call__(self, *args, **kwargs)
#    1144     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1146 with autocast_variable.enable_auto_cast_variables(
#    1147     self._compute_dtype_object
#    1148 ):
# -> 1149     outputs = call_fn(inputs, *args, **kwargs)
#    1151 if self._activity_regularizer:
#    1152     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# /home/o/Documents/thesis/highway/ddpg.ipynb Cell 11 line 2
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=19'>20</a> def call(self, state, action):
# ---> <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a>     state_value = self.fc1(tf.concat([state, action], axis = 1))
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a>     # conv_b = self.conv2(conv_a)
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=23'>24</a>     # flat = self.flatten(state_value)
#      <a href='vscode-notebook-cell:/home/o/Documents/thesis/highway/ddpg.ipynb#X13sZmlsZQ%3D%3D?line=25'>26</a>     action_value = self.fc2(state_value)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/base_layer.py:1149, in Layer.__call__(self, *args, **kwargs)
#    1144     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1146 with autocast_variable.enable_auto_cast_variables(
#    1147     self._compute_dtype_object
#    1148 ):
# -> 1149     outputs = call_fn(inputs, *args, **kwargs)
#    1151 if self._activity_regularizer:
#    1152     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/layers/core/dense.py:241, in Dense.call(self, inputs)
#     237         outputs = tf.nn.embedding_lookup_sparse(
#     238             self.kernel, ids, weights, combiner="sum"
#     239         )
#     240     else:
# --> 241         outputs = tf.matmul(a=inputs, b=self.kernel)
#     242 # Broadcast kernel to inputs.
#     243 else:
#     244     outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py:3754, in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, output_type, name)
#    3748 if transpose_b and adjoint_b:
#    3749   raise ValueError(
#    3750       f"Only one of `transpose_b` and `adjoint_b` can be True. "
#    3751       f"Received `transpose_b`={transpose_b}, "
#    3752       f"`adjoint_b`={adjoint_b}.")
# -> 3754 if context.executing_eagerly():
#    3755   if not isinstance(a, (ops.EagerTensor, _resource_variable_type)):
#    3756     a = ops.convert_to_tensor(a, name="a")
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/context.py:2272, in executing_eagerly()
#    2268   """Returns the operation seed generated based on global seed."""
#    2269   return context()._internal_operation_seed()  # pylint: disable=protected-access
# -> 2272 @tf_export("executing_eagerly", v1=[])
#    2273 def executing_eagerly():
#    2274   """Checks whether the current thread has eager execution enabled.
#    2275
#    2276   Eager execution is enabled by default and this API returns `True`
#    (...)
#    2324     `True` if the current thread has eager execution enabled.
#    2325   """
#    2326   ctx = context_safe()
#
# KeyboardInterrupt:
